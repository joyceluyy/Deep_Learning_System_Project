# %%
import os
import pickle
import numpy as np
import pandas as pd
from collections import Counter

# %% [markdown]
# ### Data Preprocessing

# %%
def load_data(path):
    """
    Load Dataset from File
    """
    input_file = os.path.join(path)
    with open(input_file, "r") as f:
        data = f.read()

    return data

def preprocess_and_save_data(dataset_path, token_lookup, create_lookup_tables):
    """
    Preprocess Text Data
    """
    text = load_data(dataset_path)
    
    # Ignore notice, since we don't use it for analysing the data
    text = text[81:]

    token_dict = token_lookup()
    for key, token in token_dict.items():
        text = text.replace(key, ' {} '.format(token))

    text = text.lower()
    text = text.split()

    vocab_to_int, int_to_vocab = create_lookup_tables(text + list(SPECIAL_WORDS.values()))
    int_text = [vocab_to_int[word] for word in text]
    pickle.dump((int_text, vocab_to_int, int_to_vocab, token_dict), open('preprocess.p', 'wb'))

def load_preprocess():
    """
    Load the Preprocessed Training data and return them in batches of <batch_size> or less
    """
    return pickle.load(open('preprocess.p', mode='rb'))

# %%
scripts = pd.read_csv('./data/scripts.csv', index_col=0)
scripts.head()
# Out:
#   Character                                           Dialogue  EpisodeNo  \
# 0     JERRY  Do you know what this is all about? Do you kno...        1.0
# 1     JERRY  (pointing at Georges shirt) See, to me, that b...        1.0
# 2    GEORGE                                   Are you through?        1.0
# 3     JERRY             You do of course try on, when you buy?        1.0
# 4    GEORGE  Yes, it was purple, I liked it, I dont actuall...        1.0
#
#      SEID  Season
# 0  S01E01     1.0
# 1  S01E01     1.0
# 2  S01E01     1.0
# 3  S01E01     1.0
# 4  S01E01     1.0

# %%
scripts[['Character', 'Dialogue']].groupby(['Character']).count().sort_values(by='Dialogue',ascending=False).head(10)
# Out:
#            Dialogue
# Character
# JERRY         14786
# GEORGE         9708
# ELAINE         7983
# KRAMER         6664
# NEWMAN          640
# MORTY           505
# HELEN           471
# FRANK           436
# SUSAN           379
# [Setting        293

# %% [markdown]
# **The main characters are JERRY(has 14786 dialogues), GEORGE(9708 dialogues), ELAINE(7983 dialogues) and KRAMER(6664 dialogues). One can see that the rest character has 10x less dialogues afterwards. To maintain the characteristics of each role, we will train the RNN model for each of them respectively.**

# %%
def convert_to_role_dialogue(r):
    return r[0].lower()+": "+ r[1]

# %%
# scripts['char_dial'] = scripts[['Character', 'Dialogue']].apply(convert_to_role_dialogue)
scripts['char_dial'] = scripts['Character'].str.lower()+': '+scripts['Dialogue']
scripts.head()
# Out:
#   Character                                           Dialogue  EpisodeNo  \
# 0     JERRY  Do you know what this is all about? Do you kno...        1.0
# 1     JERRY  (pointing at Georges shirt) See, to me, that b...        1.0
# 2    GEORGE                                   Are you through?        1.0
# 3     JERRY             You do of course try on, when you buy?        1.0
# 4    GEORGE  Yes, it was purple, I liked it, I dont actuall...        1.0
#
#      SEID  Season                                          char_dial
# 0  S01E01     1.0  jerry: Do you know what this is all about? Do ...
# 1  S01E01     1.0  jerry: (pointing at Georges shirt) See, to me,...
# 2  S01E01     1.0                           george: Are you through?
# 3  S01E01     1.0      jerry: You do of course try on, when you buy?
# 4  S01E01     1.0  george: Yes, it was purple, I liked it, I dont...

# %%
# scripts[['char_dial']].to_csv(r'./data/test.txt', header=None, index=None, sep='\n', mode='a')

# %%
for i in ['jerry', 'george', 'elaine', 'kramer']:
    temp = scripts[scripts.Character == i.upper()]
    print(temp.head())
    temp[['char_dial']].to_csv(r'./data/{i}_script.txt'.format(i=i), header=None, index=None, sep='\n', mode='a')
# Out:
#   Character                                           Dialogue  EpisodeNo  \
# 0     JERRY  Do you know what this is all about? Do you kno...        1.0
# 1     JERRY  (pointing at Georges shirt) See, to me, that b...        1.0
# 3     JERRY             You do of course try on, when you buy?        1.0
# 5     JERRY                               Oh, you dont recall?        1.0
# 7     JERRY  Well, senator, Id just like to know, what you ...        1.0
#
#      SEID  Season                                          char_dial
# 0  S01E01     1.0  jerry: Do you know what this is all about? Do ...
# 1  S01E01     1.0  jerry: (pointing at Georges shirt) See, to me,...
# 3  S01E01     1.0      jerry: You do of course try on, when you buy?
# 5  S01E01     1.0                        jerry: Oh, you dont recall?
# 7  S01E01     1.0  jerry: Well, senator, Id just like to know, wh...
#    Character                                           Dialogue  EpisodeNo  \
# 2     GEORGE                                   Are you through?        1.0
# 4     GEORGE  Yes, it was purple, I liked it, I dont actuall...        1.0
# 6     GEORGE  (on an imaginary microphone) Uh, no, not at th...        1.0
# 9     GEORGE  Are, are you sure this is decaf? Wheres the or...        1.0
# 13    GEORGE  How come youre not doin the second show tomorrow?        1.0
#
#       SEID  Season                                          char_dial
# 2   S01E01     1.0                           george: Are you through?
# 4   S01E01     1.0  george: Yes, it was purple, I liked it, I dont...
# 6   S01E01     1.0  george: (on an imaginary microphone) Uh, no, n...
# 9   S01E01     1.0  george: Are, are you sure this is decaf? Where...
# 13  S01E01     1.0  george: How come youre not doin the second sho...
#     Character                                           Dialogue  EpisodeNo  \
# 215    ELAINE  Coccoon II The Return. I guess they didnt like...        1.0
# 217    ELAINE  Okay, whatre we doing here? I have seen everyt...        1.0
# 219    ELAINE                                        Oh, lovely.        1.0
# 221    ELAINE             What do you think their parents think?        1.0
# 223    ELAINE  Yknow what? This would be a really funny gift ...        1.0
#
#        SEID  Season                                          char_dial
# 215  S01E01     1.0  elaine: Coccoon II The Return. I guess they di...
# 217  S01E01     1.0  elaine: Okay, whatre we doing here? I have see...
# 219  S01E01     1.0                                elaine: Oh, lovely.
# 221  S01E01     1.0     elaine: What do you think their parents think?
# 223  S01E01     1.0  elaine: Yknow what? This would be a really fun...
#     Character                                           Dialogue  EpisodeNo  \
# 144    KRAMER  Do you handle any of that commercial...real es...        1.0
# 458    KRAMER                                                Hi.        1.0
# 461    KRAMER              Hey Morty! (to Jerry) Salad dressing?        1.0
# 467    KRAMER                             Quo? Thats not a word.        1.0
# 491    KRAMER  No, you dont have to challenge that. Thats a w...        1.0
#
#        SEID  Season                                          char_dial
# 144  S01E01     1.0  kramer: Do you handle any of that commercial.....
# 458  S01E01     1.0                                        kramer: Hi.
# 461  S01E01     1.0      kramer: Hey Morty! (to Jerry) Salad dressing?
# 467  S01E01     1.0                     kramer: Quo? Thats not a word.
# 491  S01E01     1.0  kramer: No, you dont have to challenge that. T...

# %%
# data_dir = './data/{i}_script.txt'.format(i='kramer')
data_dir = './data/Seinfeld_Scripts.txt'
print(data_dir)
# Out:
# ./data/Seinfeld_Scripts.txt

# %%
text = load_data(data_dir)
view_line_range = (30, 50)

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in text.split()})))

lines = text.split('\n')
print('Number of lines: {}'.format(len(lines)))
word_count_line = [len(line.split()) for line in lines]
print('Average number of words in each line: {}'.format(np.average(word_count_line)))

print()
print('The lines {} to {}:'.format(*view_line_range))
print('\n'.join(text.split('\n')[view_line_range[0]:view_line_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 46367
# Number of lines: 109233
# Average number of words in each line: 5.544240293684143
#
# The lines 30 to 50:
# george: wait a second, wait a second, what coming in, what woman is coming in?
#
# jerry: i told you about laura, the girl i met in michigan?
#
# george: no, you didnt!
#
# jerry: i thought i told you about it, yes, she teaches political science? i met her the night i did the show in lansing...
#
# george: ha.
#
# jerry: (looks in the creamer) theres no milk in here, what...
#
# george: wait wait wait, what is she... (takes the milk can from jerry and puts it on the table) what is she like?
#
# jerry: oh, shes really great. i mean, shes got like a real warmth about her and shes really bright and really pretty and uh... the conversation though, i mean, it was... talking with her is like talking with you, but, you know, obviously much better.
#
# george: (smiling) so, you know, what, what happened?
#
# jerry: oh, nothing happened, you know, but is was great.

# %%
def create_lookup_tables(text):
    """
    Create lookup tables for vocabulary
    :param text: The text of tv scripts split into words
    :return: A tuple of dicts (vocab_to_int, int_to_vocab)
    """
    chars = sorted(list(set(text))) # getting all unique chars
    print('total chars: ', len(chars))
    char_indices = dict((c, i) for i, c in enumerate(chars))
    indices_char = dict((i, c) for i, c in enumerate(chars))
    return chars, (char_indices, indices_char)

# %%
def token_lookup():
    """
    Generate a dict to turn punctuation into a token.
    :return: Tokenized dictionary where the key is the punctuation and the value is the token
    """
    return {
        '.': '||Period||',
        ',': '||Comma||',
        '"': '||Quotation_Mark||',
        ';': '||Semicolon||',
        '!': '||Exclamation_Mark||',
        '?': '||Question_Mark||',
        '(': '||Left_Parentheses||',
        ')': '||Right_Parentheses||',
        '-': '||Dash||',
        '\n': '||Return||'
        }

# %%
SPECIAL_WORDS = {'PADDING': '<PAD>'}
# preprocess_and_save_data(data_dir, token_lookup, create_lookup_tables)

# %%
vocabulary = sorted(list(set(text)))
char_to_indices = dict((c, i) for i, c in enumerate(vocabulary))
indices_to_char = dict((i, c) for i, c in enumerate(vocabulary))

# %%
max_length = 20
steps = 5
sentences = []
next_chars = []
for i in range(0, len(text) - max_length, steps):
    sentences.append(text[i: i + max_length])
    next_chars.append(text[i + max_length])
      
# Hot encoding each character into a boolean vector
  
# Initializing a matrix of boolean vectors with each column representing
# the hot encoded representation of the character
X = np.zeros((len(sentences), max_length, len(vocabulary)), dtype = np.bool)
y = np.zeros((len(sentences), len(vocabulary)), dtype = np.bool)
  
# Placing the value 1 at the appropriate position for each vector
# to complete the hot-encoding process
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_to_indices[char]] = 1
        y[i, char_to_indices[next_chars[i]]] = 1

# %%
def prepare_train(text, max_length, step):
    sentences = []
    next_chars = []
    for i in range(0, len(text) - max_length, steps):
        sentences.append(text[i: i + max_length])
        next_chars.append(text[i + max_length])

    # Hot encoding each character into a boolean vector

    # Initializing a matrix of boolean vectors with each column representing
    # the hot encoded representation of the character
    X = np.zeros((len(sentences), max_length, len(vocabulary)), dtype = np.bool)
    y = np.zeros((len(sentences), len(vocabulary)), dtype = np.bool)

    # Placing the value 1 at the appropriate position for each vector
    # to complete the hot-encoding process
    for i, sentence in enumerate(sentences):
        for t, char in enumerate(sentence):
            X[i, t, char_to_indices[char]] = 1
            y[i, char_to_indices[next_chars[i]]] = 1
    return X, y

# %% [markdown]
# ## Build GRU model

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
  
import numpy as np
import tensorflow as tf
  
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM, GRU
  
from keras.optimizers import RMSprop
  
from keras.callbacks import LambdaCallback
from keras.callbacks import ModelCheckpoint
from keras.callbacks import ReduceLROnPlateau
import random
import sys

# %%
# Initializing the GRU network
model = Sequential()
  
# Defining the cell type
model.add(GRU(128, input_shape =(max_length, len(vocabulary))))
  
# Defining the densely connected Neural Network layer
model.add(Dense(len(vocabulary)))
  
# Defining the activation function for the cell
model.add(Activation('softmax'))
  
# Defining the optimizing function
optimizer = RMSprop(lr = 0.01)
  
# Configuring the model for training
model.compile(loss ='categorical_crossentropy', optimizer = optimizer)

# %%
# Helper function to sample an index from a probability array
def sample_index(preds, temperature = 1.0):
# temperature determines the freedom the function has when generating text
  
    # Converting the predictions vector into a numpy array
    preds = np.asarray(preds).astype('float64')
  
    # Normalizing the predicitons array
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
  
    # The main sampling step. Creates an array of probablities signifying
    # the probability of each character to be the next character in the 
    # generated text
    probas = np.random.multinomial(1, preds, 1)
  
    # Returning the character with maximum probability to be the next character
    # in the generated text
    return np.argmax(probas)

# %%
# Helper function to generate text after the end of each epoch
def on_epoch_end(epoch, logs):
    print()
    print('----- Generating text after Epoch: % d' % epoch)
  
    # Choosing a random starting index for the text generation
    start_index = random.randint(0, len(text) - max_length - 1)
  
    # Sampling for different values of diversity
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)
  
        generated = ''
  
        # Seed sentence
        sentence = text[start_index: start_index + max_length]
  
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)
  
        for i in range(400):
            # Initializing the predicitons vector
            x_pred = np.zeros((1, max_length, len(vocabulary)))
  
            for t, char in enumerate(sentence):
                x_pred[0, t, char_to_indices[char]] = 1.
  
            # Making the predictions for the next character
            preds = model.predict(x_pred, verbose = 0)[0]
  
            # Getting the index of the most probable next character
            next_index = sample_index(preds, diversity)
  
            # Getting the most probable next character using the mapping built
            next_char = indices_to_char[next_index]
  
            # Building the generated text
            generated += next_char
            sentence = sentence[1:] + next_char
  
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Defining a custom callback function to 
# describe the internal states of the network
print_callback = LambdaCallback(on_epoch_end = on_epoch_end)

# %%
# Defining a helper function to save the model after each epoch
# in which the loss decreases
# filepath = "weights_{i}.hdf5".format(i='kramer')
filepath = "weights.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor ='loss',verbose = 1, save_best_only = True,mode ='min')

# %%
# Defining a helper function to reduce the learning rate each time
# the learning plateaus
reduce_alpha = ReduceLROnPlateau(monitor ='loss', factor = 0.2,patience = 1, min_lr = 0.001)
callbacks = [print_callback, checkpoint, reduce_alpha]

# %%
# Training the GRU model
model.fit(X, y, batch_size = 128, epochs = 40, callbacks = callbacks)
# Out:
# Epoch 1/40
# 5425/5425 [==============================] - 27s 5ms/step - loss: 1.7555
#
# ----- Generating text after Epoch:  0
# ----- diversity: 0.2
# ----- Generating with seed: "i'm lost now, kramer"
# i'm lost now, kramer!
#
# jerry: (loughing and here hard the carend and the changer and what are you should had the care and her down and her and you know you have to see hor and what is the manding to the come in the come in the caren and i have to me her hard in the come grander there and here word hore who hard the man and what happened?
#
# jerry: hey, i have the changer and her like a her hard hard hor my and what a
# ----- diversity: 0.5
# ----- Generating with seed: "i'm lost now, kramer"
# i'm lost now, kramer! what do you gotta have who don't want this got the lovernis hard and word end you have are word the raching are your loughting as it of it stunfriend) what?
#
# jerry: hey, you're nothing.
#
# jerry: i'm hor and the hard the one a word somework.
#
# george: well, this is no shruper with the word your my who hom.
#
# jerry: you gotta got the little from the mane of who can a little your contion.
#
# jerry:
# ----- diversity: 1.0
# ----- Generating with seed: "i'm lost now, kramer"
# i'm lost now, kramer!
#
# jerry: no!
#
# jerry: yeah- oh" we hored. just? there no. sand of thatman.
#
# strah: hey, much mo." (grannergring up) hell-s kramer!!
#
# george: elay: yeah?? the worde it(ofle. whone aposting?!
#
# kramer: who guy wodllyd?
#
# jerry: wour weder intelly, mutt workely highmen thing or word instanertry of tomanghidawargs a bashio!
#
# jerry: maybeen blayit facted wordly..(ckem "m maneriterbing women like t
# ----- diversity: 1.2
# ----- Generating with seed: "i'm lost now, kramer"
# i'm lost now, kramer? manally! xemponisacodd momy.. prwegred, frucks inbwor rigjaflarb! (entirners at this) oh! excusi'm my shour? thanks if hocanisan oun acilurens.
#
# denfy conger: no son...) no that tymer?
#
# jerry: i know in grinners me hur?
#
# jerry: alright? yed o kers you niwmenthing long thing juneing for there vife? (to rayionly acy" out.
#
# george: yerey. no, guy her dayen yout doel coqued) oh!
#
# george: yes.
#
#
# Epoch 00001: loss improved from inf to 1.59982, saving model to weights.hdf5
# Epoch 2/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.4852
#
# ----- Generating text after Epoch:  1
# ----- diversity: 0.2
# ----- Generating with seed: "
#
# jerry: i didn't-- "
#
#
# jerry: i didn't--
#
# kramer: yeah.
#
# george: i don't know what i don't know what i don't know what the mover word and i want to go on the post to got the poon of for the patter.
#
# george: yeah.
#
# george: well i want to get the post to get the move the wear the point the pooring the pate on the door.
#
# jerry: what do you know what i was the post to get the past to get the poon.
#
# george: well, i don't know what i was
# ----- diversity: 0.5
# ----- Generating with seed: "
#
# jerry: i didn't-- "
#
#
# jerry: i didn't--
#
# jerry: what happened to do you know what that hear too been in the bather.
#
# jerry: hey, costriver business back.
#
# george: there is sonine the move so, my got the bothing on the place.
#
# jerry: (ton heald) i walked to get here?
#
# elaine: george, i'll got the countract of the poisthing on the couth.
#
# george: well i'm gonna be a little heard that we think will you to know what that i have the pi
# ----- diversity: 1.0
# ----- Generating with seed: "
#
# jerry: i didn't-- "
#
#
# jerry: i didn't--
#
# george: they're scopment the punke'esse]
#
# tra cont!
#
# elaine: allinge, listec an eugh...no it's scorpsing of the patting. (he coine) got his working about herc happened? little jue about on yearss knaw triothing?
#
# hrat: now, you both thank.
#
# george: (the dairor. im enter you won and mys forethread.
#
# alrie: (toinu) he wionk of ciotod my pointing. i.!
#
# kramer: (goedely us the apartmone.
#
# jed
# ----- diversity: 1.2
# ----- Generating with seed: "
#
# jerry: i didn't-- "
#
#
# jerry: i didn't--
#
# hol vale. don't wonding anything onn..ing onthing and say? and is door our pate will.
#
# brie.: pot to really?..an? he's a llack. that. jerry, you got dinnoabody. show. you don't pock gonna?
#
# joy: junzo) hi i potting i no.?
#
# lisppthole: elaine? i took the. what you onlan. i need ticked.
#
# george: listened won like tolcor up i i'm. she won inwanters. wrothe. wait i are yourgeting and you have hi
#
# Epoch 00002: loss improved from 1.59982 to 1.48576, saving model to weights.hdf5
# Epoch 3/40
# 5425/5425 [==============================] - 26s 5ms/step - loss: 1.4699
#
# ----- Generating text after Epoch:  2
# ----- diversity: 0.2
# ----- Generating with seed: " sounds, elaine answ"
#  sounds, elaine answer the the worked to the stay the stay the the come to the stay the popticate the to the care the stay the the content.
#
# elaine: well, the stay the content.
#
# elaine: the stay the come to me the tayes the come to the stay the the to the town the conting the tersanted to the time.
#
# elaine: well, it's the come to the care the come to do the stay the contan the come on the come on the the content.
# ----- diversity: 0.5
# ----- Generating with seed: " sounds, elaine answ"
#  sounds, elaine answerstanday the contan monther to the perpore in the peace the manary something the coat....it's the stay standay.
#
# elaine: well.............
#
# elaine: we don't start the stay to stay the down the trugus the the intected to the wile to the bather to the stand.
#
# elaine: oh, they say the one the perpy of the done to the come of the stay on the the to the forty to the doing my tow it the car the seel
# ----- diversity: 1.0
# ----- Generating with seed: " sounds, elaine answ"
#  sounds, elaine answer my suge.
#
# elaine: who is stetre.
#
# dides: his my pronat. we're train and work. you take something me steind) these sayin' me?
#
# jerry: oh, the hack. we had a cturmard uth to the stapstace themet in the say puldinc.) my spop. i thouldny' love a woman whated urday.
#
# maremed: (treather the sleation winace jurther. the fund.
#
# george: we cajus thetstever) elled it. (the kid) i'm lared byed.s.
#
# j
# ----- diversity: 1.2
# ----- Generating with seed: " sounds, elaine answ"
#  sounds, elaine answere now take taxi. not fills going the sterp" t stee stay to the t..
#
# elaine: not to they t's get them phonmon shes into.bate doors they with it bye?
#
# mruskarel: telve the )ley) i'm they die speak"
#
# wied: why's these...]
#
# elaine: so my homen domay...it.. he's to.
#
# tima: here like the guys, excruse ride the chiase chiles a prantps is trying motty back)
#
# maali: woad.'s the chent the voe lobion
#
# Epoch 00003: loss improved from 1.48576 to 1.47363, saving model to weights.hdf5
# Epoch 4/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.4750
#
# ----- Generating text after Epoch:  3
# ----- diversity: 0.2
# ----- Generating with seed: "pan) oh, i don't kno"
# pan) oh, i don't know.
#
# george: yeah, i got a good to got to got to something to got to be a good toor of the poor for the ports on the for the really the got to got to the trange to the go to got to got to the trane to got to be a going to the god the possible to got to the toor too his in the good.
#
# george: what is the good the poor of the poor of the god the poor of the new the good to the bottle to the better t
# ----- diversity: 0.5
# ----- Generating with seed: "pan) oh, i don't kno"
# pan) oh, i don't know.
#
# george: that is the some for the really for the kine to been and thing one the really and the george one to do you got to got to hand or a grably with it on there good.
#
# kramer: oh, i got a guy not a comes to are you toor door for these the poor on the really then i gotta go to got the going?
#
# george: i got to just on the jobse to do you know the book thing with the king in there going to b
# ----- diversity: 1.0
# ----- Generating with seed: "pan) oh, i don't kno"
# pan) oh, i don't know, anrweral going to womes? (ragrshing the conding?
#
# laine: was tay backloo, nerving "great? (nother)
#
# george: voick about you pan it. and i'm ahop.
#
# george: right.
#
# jerry: i got oome trying and goed.
#
# george: i'm hor's taning apliok you!
#
# george: no, . hows got spong.
#
# grable nothone.
#
# elaine: oh oh, how, you don?
#
# george: well, thiser dissecoune.
#
# liviove: yeah, excaught.
#
# george: thi
# ----- diversity: 1.2
# ----- Generating with seed: "pan) oh, i don't kno"
# pan) oh, i don't know.
#
# jicker: (to up colouttood): with yeen trying iw.
#
# and thoagr ban:, doo's a nussing your bool that jastagght ov.
#
# jerry: or one cogr, go i'm pirpanon!
#
# george: no, no, come on, (giulting) ay'giper ctat, you retrent  you for how, so (your at) i toochin't, (trante) i jugures.
#
# [setting doess elved?
#
# george: is, i got new fyuldn youm no joboody. i or everd
#
# prys: csuse you, comps her ute. l
#
# Epoch 00004: loss did not improve from 1.47363
# Epoch 5/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.3822
#
# ----- Generating text after Epoch:  4
# ----- diversity: 0.2
# ----- Generating with seed: "b?! (frustrated)
#
# j"
# b?! (frustrated)
#
# jerry: i don't know what i don't know that the store to the possible.
#
# jerry: yeah, i don't know what i don't know what i don't know what i don't want to see that the counter.
#
# jerry: i don't know what i don't know what i don't know what i don't know what i don't know what i don't know what i don't know what i don't know that the bathroom.
#
# jerry: i don't know what i don't know that is the care.
# ----- diversity: 0.5
# ----- Generating with seed: "b?! (frustrated)
#
# j"
# b?! (frustrated)
#
# jerry: the couple that will go that that the george. the stuck to the standing a standing of a problem. it's a friend of the talking and sitting to you.
#
# elaine: i don't know the makes a party back and the stupid to the postion.
#
# george: oh, uh, how does you didn't it.
#
# george: i don't know the lot to the thing you that that i think you got that tristing in the friends. i don't know the silling
# ----- diversity: 1.0
# ----- Generating with seed: "b?! (frustrated)
#
# j"
# b?! (frustrated)
#
# jerry: so i don't ath. sink, i'll really like . . i'm sood. (think down)
#
# jerry: u, georgeing, really.
#
# george: o have!
#
# jerry: really, palepment progs in my lateraurter. he have it. all right.
#
# ai: i'll even pock in. the enistld and lotic!
#
# suchely: so, a lacch interright a muthrorne?
#
# jerry: look, i'l glart syeck to him a says a phone stupids.
#
# george: from my tabing that?
#
# marty elaine:
# ----- diversity: 1.2
# ----- Generating with seed: "b?! (frustrated)
#
# j"
# b?! (frustrated)
#
# jerry: marrian dake the naving you. she's she ned? i loigt back up. sop, alright, ey me i bet? youre renure.
#
# jerry: you touching, hea entrualls comes that if jow has all thain i wouldgon, you're up?
#
# peterman: (hound the sockebrorught that? this is it.
#
# george: ampontcuyingicic?
#
# hahry: yas! is today his actanceage shows elaine! you're, john, act. dids you bad uptiteas?
#
# jecry: room. aren't i
#
# Epoch 00005: loss improved from 1.47363 to 1.36154, saving model to weights.hdf5
# Epoch 6/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.3262
#
# ----- Generating text after Epoch:  5
# ----- diversity: 0.2
# ----- Generating with seed: "he way he left, you "
# he way he left, you know what i don't know what i was the standing to the stan to the stearing to the show the card of the standing the care and the story the steal the care to the conting to the card to me a seen when you don't want to get the come to be the standing the come to be the standing and the stan and we was to the come in the card to the standing to the steal the bathroom here and so the standing to the s
# ----- diversity: 0.5
# ----- Generating with seed: "he way he left, you "
# he way he left, you think all the cand out?
#
# kramer: hey, what are you hangs that the time, she was to you a card that things of this.
#
# george: what are you going to funny)
#
# kramer: what are you doing?
#
# kramer: what?
#
# kramer: what do you think my stanted they should i shows this guy for the guy and so the new who you be a little with the show the seven a who wouldn't never come on the show to the girged at the s
# ----- diversity: 1.0
# ----- Generating with seed: "he way he left, you "
# he way he left, you were on frges happens?
#
# jerry: are you doing?
#
# kramer: hey can you good?
#
# krume: theirs years that like the mutallicy beforaess.ing.
#
# elaine: this is george guy. heps! so not tell me and brone grotle poppicion?
#
# newman: (to (peocting to thosever in me auple boy'fine.
#
# helen: hey, they did that sit toorap.
#
# elaine: well i pausess ustation) george three necos.
#
# kramer: tell must besware?
#
# g
# ----- diversity: 1.2
# ----- Generating with seed: "he way he left, you "
# he way he left, you onlimit too, in, tanod pan. come in.....
#
# volien...i just see whhebehold shart?!!
#
# jerry: you sep.)
#
# celleen: youx surpric wifes. jerry ! is the shoot.
#
# elaine: sour's tabsrmous osparss morty actuach punlist weallostross jerry
#
# jerry: so i thoughzad?
#
# kramer: keay, ho' hit's it at?
#
# kramer: consolo kellineshanmence her actorar?
#
# heica:ley): kramer! this is like me the elstinedah?
#
# newman:
#
# Epoch 00006: loss improved from 1.36154 to 1.32303, saving model to weights.hdf5
# Epoch 7/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.3049
#
# ----- Generating text after Epoch:  6
# ----- diversity: 0.2
# ----- Generating with seed: "t your purse.
#
# jerr"
# t your purse.
#
# jerry: hey, hey, hey, i don't know what the starts.
#
# jerry: i don't know what i was the course to him on the starting the counter.
#
# jerry: oh, no, no, no, that's the store of the book here.
#
# jerry: i don't know what the convication of the store on the course of the store of the couple of the comedion.
#
# jerry: yeah, i got the couch of the show it to the show that the store of the store of the convi
# ----- diversity: 0.5
# ----- Generating with seed: "t your purse.
#
# jerr"
# t your purse.
#
# jerry: yeah, hey, the listen, there you think you could be the haing look up the boy) i know, i don't know what you had to say me?
#
# jerry: i don't know what it would go to talk to him the one care ho this it a starting in the single.
#
# jerry: what's that?
#
# kramer: what's the coming to the couple man in the commity.
#
# jerry: oh, what is the one on the moviden the counter in the pobent for the store i
# ----- diversity: 1.0
# ----- Generating with seed: "t your purse.
#
# jerr"
# t your purse.
#
# jerry: hey.
#
# jerry: how'd the sick?! i was a never you put here? im coutio! good why okay, shrmm storry. yes and napet they it, i'm pcrolityed, ash you shottious my and about the roads hue! is merticates - maybe an girl leaning to be vkransication other.
#
# jerry: listing in tomorrow old door in there! scamine poin.
#
# elaine: why tong to manah.
#
# jerry: this is it. (contures that funny. he's not no te
# ----- diversity: 1.2
# ----- Generating with seed: "t your purse.
#
# jerr"
# t your purse.
#
# jerry: what's arrical you
#
# sid: evary ozg, i'm not out of that at tal'. i've love to mill.
#
# george: but what don't?
#
# janic tosh a strains.
#
# frast: giv'? my offainy diging me, bad. (truged laughs off) oh, . now that know, mrhm helh.. and i can get is.
#
# kramer: hhhhh, no, ! she's mores!! i smekt i had to you it. heally do you ... (my" ug) hehehs! you don't becvite in a lot, and wook thucks one (jer
#
# Epoch 00007: loss improved from 1.32303 to 1.30564, saving model to weights.hdf5
# Epoch 8/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2872
#
# ----- Generating text after Epoch:  7
# ----- diversity: 0.2
# ----- Generating with seed: "t back to him.
#
# kra"
# t back to him.
#
# kramer: (to her worded) i don't know what i was a good the friend is gonna get the book for the couple of the same of the money.
#
# jerry: yeah, i have to get a lot of the party.
#
# jerry: what are you doing?
#
# jerry: what do you have to get on the seen and she was a see him of the words and the seen here is a little with the should be a change and he was a little for the should be a chare with the sho
# ----- diversity: 0.5
# ----- Generating with seed: "t back to him.
#
# kra"
# t back to him.
#
# kramer: i see you thing. i can't started the words.
#
# jerry: oh, no, why don't have you that i asked the say it a lot of very place.
#
# jerry: (to back, to the lot of the say when i think you didn't come up.
#
# elaine: well, it's an books an in a starts with the back up in the move the bathroom with my guy and you want to do that?
#
# jerry: hey, and they can think he are the friend of she was the denity
# ----- diversity: 1.0
# ----- Generating with seed: "t back to him.
#
# kra"
# t back to him.
#
# kramer: well jerry, i have to the listers) no i gotha. um, eza! i, that's junes.
#
# george: its personale, that tew down you say idea "when you should have not - woman on keep enter wear hi.
#
# elaine: hey, whitely meesing. oh georgie. funestup noch. ah! i, you want at kind of herred, your clack! get you just turn what you but hack?
#
# sarol: no well, she deaiden don't him.
#
# tabner: there's gonna go th
# ----- diversity: 1.2
# ----- Generating with seed: "t back to him.
#
# kra"
# t back to him.
#
# kramer: xack from him (thinks hi) ill prokoulyoge holist des. goda. but yeah, vervists on sokin theysorrusening, inde. doess in this winners? okay, great of, byl.
#
# righbo. a boggebrane, you ever talk of? elaine. ykah! hey! thisgiany?
#
# yeldna: right.
#
# homera yeake: well,, ie to the bladiog and to her.
#
# jack: can seting ghonve) um inswerl. you're davis and got jacks my . like a cade atcheack.
#
# til
#
# Epoch 00008: loss improved from 1.30564 to 1.29402, saving model to weights.hdf5
# Epoch 9/40
# 5425/5425 [==============================] - 26s 5ms/step - loss: 1.2805
#
# ----- Generating text after Epoch:  8
# ----- diversity: 0.2
# ----- Generating with seed: "e take stock of my l"
# e take stock of my life to the comedione.
#
# jerry: i can't be the car.
#
# kramer: you know what you got a come of the card and the care of the cart of the car the car of the card of the couple and the movie was the face of the back and the card of the card of the hampie of the standing and the car and the car the car to the card of the card of the car and the car and the store to the card of the cart and the car.
#
# je
# ----- diversity: 0.5
# ----- Generating with seed: "e take stock of my l"
# e take stock of my lips to get a come down and the way the course of her and she do it on the came this mail of a lot on the movies and the mother because he was not pasting in the card and the baby?
#
# jerry: oh yeah, i think you know what are you the back on the pointically for the second.
#
# jerry: i got a coming of the says of the cound the card for the people of the street with the card considing and the friend of
# ----- diversity: 1.0
# ----- Generating with seed: "e take stock of my l"
# e take stock of my lobc costert dolly am i  weathing you to did then he atan a li can i salaom into the kets that?
#
# elaine: (possil and showing) george.
#
# elaine: (lvanstily goes coocon. george and fill right there care and bail dinner. (to good join packets from your good ideay... in crinds, they're a clopper?
#
# bunch: what? we mean, a come to mreeno? - that's ad carely about you. he happen hung press.
#
# maphey: yo
# ----- diversity: 1.2
# ----- Generating with seed: "e take stock of my l"
# e take stock of my longer.) alrikit! , elaine?
#
# jerry: let's like a isable. thgy's even jijg.
#
# george: good.
#
# kusn! what are?
#
# iftic: i'm guran other.
#
# george: so revofifil- you communced to whon your almo!
#
# hemering: (she for a goo saliar. elaine?s! you're unmeraway, but at there acciouse with down of averiby anymore, tanim.
#
# raikies with the office that we said beet get you's streck larcon.
#
# george: gonna m
#
# Epoch 00009: loss improved from 1.29402 to 1.28525, saving model to weights.hdf5
# Epoch 10/40
# 5425/5425 [==============================] - 26s 5ms/step - loss: 1.2728
#
# ----- Generating text after Epoch:  9
# ----- diversity: 0.2
# ----- Generating with seed: "ing and blocking som"
# ing and blocking some stuck out of the store of a see a see you and i was the store.
#
# kramer: yeah, i don't know what are you starting the store of the party to the steenner.
#
# kramer: yeah, you know, i don't know what i said that she want to see you to the story and i think you say a little of the store of the story.
#
# elaine: what is the steady?
#
# elaine: i don't know what are you doing the card?
#
# kramer: yeah, y
# ----- diversity: 0.5
# ----- Generating with seed: "ing and blocking som"
# ing and blocking some window.
#
# kramer: so i can't be some good back.
#
# jerry: i don't have any in the poor thing.
#
# jerry: i was the mother.
#
# elaine: well, i say you say some hand and i saying to you anyway.
#
# george: (to see her oot and stand man first hold and the standing of your sounds in that why and i think you know its the bad because he be so bether face anything a the face your stan in the bathroom.
#
# jerr
# ----- diversity: 1.0
# ----- Generating with seed: "ing and blocking som"
# ing and blocking some great wrean about goes the bathroom)
#
# jerry: s eacsthing in for it calleds other.
#
# darren: your far hearnt.
#
# jerry: what to kill because but we as a looking away, do you call to and gettion.
#
# kramer: he take you. you want your mation. i let you mean there's lood from her of cleaning of between, looks about...
#
# elaine: oh killald. puy there?
#
# kexs mancef.
#
# morty: no.
#
# jerry: um, (he gives
# ----- diversity: 1.2
# ----- Generating with seed: "ing and blocking som"
# ing and blocking something out to me tatting tey! riving so, do he never, you were i can take us, absorn, livin' work. bourogs his here move issure idea.
#
# iaulany: crusse-ha saleg. i don't cald to catitra, that's wondeag, placed. pay cloalfly getting. it's guajok locket his nuce.
#
# voipation: did thil-you....do it?
#
# el:ordidy, nother wolf we're wagjgre boot. you cauch you recall assurtion.
#
# kramer: no, the is, can
#
# Epoch 00010: loss improved from 1.28525 to 1.27876, saving model to weights.hdf5
# Epoch 11/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2674
#
# ----- Generating text after Epoch:  10
# ----- diversity: 0.2
# ----- Generating with seed: "
# elaine: so the trip"
#
# elaine: so the trip of the place and her of the standing to the back of the parents of the store.
#
# elaine: hey, i want to have to get it out of the words of the should be a should be something the store of the store.
#
# george: you know, i was the stuck of the book of the store down of the store of the point for the store.
#
# jerry: what?
#
# jerry: what?
#
# elaine: (shouts) you know, i'm sorry.
#
# jerry: i don't know wh
# ----- diversity: 0.5
# ----- Generating with seed: "
# elaine: so the trip"
#
# elaine: so the trip is starts there.
#
# elaine: hey, i mean, the cause i get a got the words and i don't know what i do that?
#
# elaine: no.
#
# elaine: well, you know, i dont know what you find that finger problem, the book of not got a books.
#
# elaine: hey, the play a pants in the spocting into the possible to the mand i thought we do this to spell in the coother, what?
#
# george: i don't know that that i don't know, y
# ----- diversity: 1.0
# ----- Generating with seed: "
# elaine: so the trip"
#
# elaine: so the trip back.
#
# george: jerry, what, why too?
#
# makolder: no, no..
#
# george: oh, port his bag.
#
# bubdra: why not?
#
# waitress: so i'm tired wondedrelling "moniycul crownsh poose to more sknt you out? you.
#
# elaine: i'm not person. i negver oved thouly you're serves aperican. noanemblis ob, i'm ar. he was happenendent from ben his heating. (for the down? he's dreath oxerselm obod.
#
# lotha: ah, yeah, it's f
# ----- diversity: 1.2
# ----- Generating with seed: "
# elaine: so the trip"
#
# elaine: so the trip .. good, tounds and orew, we - wo, is you, at maybon.. verve people. (struddinglar) thank whats then a great the couffespar! more.
#
# jerry: fiver sbif town then man
#
# elaine: no, so, take ... i have a fcludes or jerry, (to susan) yeah, i didn't woll usy. you'd up.
#
# jerry: george, ya. over my hult who? i'm seillomybody tody ive back on my "she reglight pedute. i know how are you phel fluscy.
#
# je
#
# Epoch 00011: loss improved from 1.27876 to 1.27321, saving model to weights.hdf5
# Epoch 12/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2626
#
# ----- Generating text after Epoch:  11
# ----- diversity: 0.2
# ----- Generating with seed: "eve george's cap... "
# eve george's cap...
#
# jerry: i don't know what i was a back and the story of the parents and the way the possel pick of the story.
#
# jerry: what is this?
#
# jerry: i don't want to be a back of the plane of the commones.
#
# jerry: i don't know what i don't know what i do it we should be a back.
#
# jerry: what do you want to be a lot of the read of the point to him and i don't know what i was the store of the possible of
# ----- diversity: 0.5
# ----- Generating with seed: "eve george's cap... "
# eve george's cap...
#
# jerry: oh, oh, you don't see it. it's a possible hated in here.
#
# elaine: i'll be so me, the point.
#
# mrs kramer: hey really the ready dissand and i just want to get it and i end up sexical room.
#
# man: oh, you know, i don't doing any dollars.
#
# jerry: what about that?
#
# elaine: well, what are you doing and because you a mentor.
#
# elaine: yeah, the coming and i want to do me about the machine?
#
# ----- diversity: 1.0
# ----- Generating with seed: "eve george's cap... "
# eve george's cap... in and money, kramer. alrights day've call the bator word of his of cafach.
#
# elaine: i don't colrar.
#
# bania: helves. (pastary on jerry his leo, week to unco.dir?
#
# elaine: but maybe it - boys.
#
# jerry: (over)cio-isation my or?
#
# mickey: (freaching) sounds of chicken anyway of the leoter.
#
#  delivenoleeran: there.
#
# kramer: oh, no, jerro, over can's latievale. alanry?! the openation?
#
# haida: tha
# ----- diversity: 1.2
# ----- Generating with seed: "eve george's cap... "
# eve george's cap... (people)
#
# openethiector: they the -younessna.
#
# wmm, levo's getting standard another bed! i just post a ted're veryanderemsebrorm.
#
# jerry: you know you say around.
#
# mymoo: bos,selrman, goodow, his ours and problemany uh, who wantl to tilk back someone nothourt. i'll see. i'm a hotion a woman um, thank hig what what i'm used) pas four. bomber fasted. (sombuch it) how wrong acx duph. i've goed en
#
# Epoch 00012: loss improved from 1.27321 to 1.26889, saving model to weights.hdf5
# Epoch 13/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2643
#
# ----- Generating text after Epoch:  12
# ----- diversity: 0.2
# ----- Generating with seed: "finds the key in his"
# finds the key in his some will looks and the story.
#
# jerry: what do you know what i was the party of the chance of the shower weekending to the story.
#
# george: yeah.
#
# george: well, you know, i was the chance of the way the conting to me.
#
# george: well well, i can't have to go to the story.
#
# jerry: well, i was a lot of the story.
#
# jerry: well, i was the story.
#
# jerry: well i was a second of the seen it and show
# ----- diversity: 0.5
# ----- Generating with seed: "finds the key in his"
# finds the key in his have a later of a little work to do it's a walk any back on the poper.
#
# jerry: you know, she was in the story.
#
# kramer: (to kramer) well, he was her thing the story back.
#
# jerry: it's nothing.
#
# george: what do you have to go the applea.
#
# george: what did you see this worked and news at this how my course the way there and money that for the matter miss of my second, you know what are you pic
# ----- diversity: 1.0
# ----- Generating with seed: "finds the key in his"
# finds the key in his dolpy, elaine.
#
# kramer: hey, there all in a flactionity of all coming o me?
#
# elaine: hey, are you endort peeva wasn't a the oping up chitenices it parenss, good fall, for that i'm out of something anyway) lecased, figlis poin worked, great (considels.
#
# elaine: i shouel anyway?
#
# pecka: look at the harsser, one in! i, that wascruhing out.
#
# george: hey.
#
# jerry: ma! i don't know.
#
# blick: hey,
# ----- diversity: 1.2
# ----- Generating with seed: "finds the key in his"
# finds the key in his, nixchts in your movin'?
#
# vana: hi. relically so cheece to po thousany.! (hus kramer of the fish, would you know what tony?
#
# job ninie: hey we're indical): (feet) tweg any kpreasiket.
#
# elaine: howrame.
#
# man: yey's it's good. toderead!
#
# geenning: (thres impens mutich vaaranie, tonladed to elaine hit yourechs, but "who seemings, if george? you but it! i knop. (sat a look what you malse was rar
#
# Epoch 00013: loss improved from 1.26889 to 1.26484, saving model to weights.hdf5
# Epoch 14/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2529
#
# ----- Generating text after Epoch:  13
# ----- diversity: 0.2
# ----- Generating with seed: "be a good idea to ge"
# be a good idea to get the straines.
#
# jerry: i can't take the movies the back the story.
#
# jerry: yeah.
#
# jerry: what do you know what i was that the story of the couple and the stands and starts to the stands of the couple of the story.
#
# jerry: they say the story of the movies of the movies back and the stands in the back of the story) i don't know what i was the problem the matter of the bad to the story of the mo
# ----- diversity: 0.5
# ----- Generating with seed: "be a good idea to ge"
# be a good idea to get the stands for the story.
#
# elaine: (interrupting the whole starts for the back up time.
#
# jerry: yeah.
#
# kramer: yeah.
#
# jerry: what do you mean?
#
# george: yeah.
#
# george: and there was the way the business of the friends shop, you know.
#
# jerry: no, i think you want to just want to go to tell him leave and he was the tears the story with the mession?
#
# jerry: you know where i don't know what i
# ----- diversity: 1.0
# ----- Generating with seed: "be a good idea to ge"
# be a good idea to get alai budd the into the bloded of fanded.
#
# elaine: no condom! we'll get all dand?
#
# jerry: george, thing fact so thinks she scitves old with it on james thing you're gliss's suco. it if. it's day. i don't know, steating those so mmmy.
#
# susan: well eh. do you say s-cat it?
#
# juning apprectra: not to keep my carmen wetd me concesused about ever better.
#
# george: yeah ye they save it just hanging!
# ----- diversity: 1.2
# ----- Generating with seed: "be a good idea to ge"
# be a good idea to get velcter cighoo. sppeops. you've say move to go that i-year? you did give me ook here. but koker and bituh) hello, go?
#
# jerry: what mdoble are really. he has elsebies the hock. what did?
#
# elaine: what is this?
#
# sicted: i know, like seevitesanys?
#
# vely scleyer: guy, im just that i'd find able on hours i'm dressed to past. how'd its it this agethe mefser's step of the reletme! mem fight back.
#
#
# Epoch 00014: loss improved from 1.26484 to 1.26152, saving model to weights.hdf5
# Epoch 15/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2558
#
# ----- Generating text after Epoch:  14
# ----- diversity: 0.2
# ----- Generating with seed: "
#
# pregnant woman: oh"
#
#
# pregnant woman: oh, i can't have to get and he was a bathroom.
#
# jerry: hey, i have to be a little of the back of the bathroom the conversion.
#
# jerry: i don't know what i do that the counter.
#
# jerry: you know what i think you know it's a couple of the counter.
#
# jerry: i don't know what i was the condent of the back of the friends and they have to know what i think you can they believe the hair of the couple of t
# ----- diversity: 0.5
# ----- Generating with seed: "
#
# pregnant woman: oh"
#
#
# pregnant woman: oh, you're a fine and well any down there and i mean there it thing is it of here.
#
# jerry: they make the comedonight.
#
# jerry: what do you think your street. i wello.
#
# jerry: hey, that's the call in the friends of the business.
#
# kramer: hey, how is the sen and so the bather and they have not hands to the problem of this the chance.
#
# jerry: you know what you want to take it.
#
# jerry: you know wha
# ----- diversity: 1.0
# ----- Generating with seed: "
#
# pregnant woman: oh"
#
#
# pregnant woman: oh a he brie. i think i'm a sups... i asked it a point attices, like through out i'm the only what how doessix it's just for they gotta love.
#
# kramer: hello, you could just fat to the pihe.
#
# jerry: oh buy free dance.
#
# jerry: what?lly didgle.
#
# jerry: agaisument, it's supposed...sitt let those too bada...i are face...
#
# george: elaine, alright. and i worked there a fun.'ve been side vistion on the
# ----- diversity: 1.2
# ----- Generating with seed: "
#
# pregnant woman: oh"
#
#
# pregnant woman: oh osmen ascr? spoll twerneds. look, you noany you can't need you, i carts, i loide on all tably. andying. thoseo to hij... coveentuch other approorleted a fuwn this hum.
#
# boley: oh day about you enough mi?
#
# kramer: i wanted this.
#
# george: oh, lam...sitr! she's a fathand, jerry.
#
# george: i thimk. it's not someone very man.
#
# jerry: i kneck lasted my open us mouls suppove a perfeed taura with the
#
# Epoch 00015: loss improved from 1.26152 to 1.25843, saving model to weights.hdf5
# Epoch 16/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2513
#
# ----- Generating text after Epoch:  15
# ----- diversity: 0.2
# ----- Generating with seed: "y how i would put it"
# y how i would put it.
#
# elaine: yeah.
#
# jerry: you see you a second.
#
# elaine: yeah.
#
# george: (to her starts and she was the phone of the baby.
#
# george: well, i don't know what they should see you anything to the stands of the story man something the back and the stands of the story.
#
# elaine: yeah, i was the points of the story.
#
# george: yeah, you see it?
#
# george: i don't want to be the bathroom and i got the fi
# ----- diversity: 0.5
# ----- Generating with seed: "y how i would put it"
# y how i would put it?
#
# kramer: what is that?
#
# george: what is the play?
#
# elaine: i don't know what they really get a friend, i'm sorry to get a woman who you done was this to see a little dance.
#
# elaine: i don't want to get starts.
#
# securing jerry: i'm back to the honest.
#
# jerry: so little bothation of the book and i'm in the septing to do one with a month not the strent?
#
# elaine: i saw they see the points.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "y how i would put it"
# y how i would put it 'xualy down.
#
# kramer: oh, i give'.
#
# george: ah ross. (much show the wintor obviously dinfing too black? (puts ya. (flyestandting annoy of her each bicacang elaine. i fell daying beeie and i'm an expuling me. simber whongs, that's a new man from a faunsting up on the chinness.
#
# elaine: oh, i'll like where in my infrontanole. and with so denthous. thank you, jimcil, i...
#
# kramer: you've been uh
# ----- diversity: 1.2
# ----- Generating with seed: "y how i would put it"
# y how i would put ited, if you're costay gribin coan with alled wick
#
# guljersh: now.
#
# elaine: (clating offer) elaine!
#
# skeeten: seehvad? you would do and somes.
#
# jerry: okay, i reven batzes, this isn't your face and i'd a other weekendard i got, woures he'll ganigans woddy.)
#
# jerry: puqur back. i'ving it.
#
# kramer: hey, but-you mivier for sphonap.
#
# sid a-: right? what coutse?
#
# george: yeah, he's yare and im br
#
# Epoch 00016: loss improved from 1.25843 to 1.25649, saving model to weights.hdf5
# Epoch 17/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2519
#
# ----- Generating text after Epoch:  16
# ----- diversity: 0.2
# ----- Generating with seed: "ng for me. yeah, i r"
# ng for me. yeah, i really do that was the car.
#
# kramer: you know it's the standing in the standing the money.
#
# jerry: i don't know what i think i want to go to the standing the come of the time.
#
# jerry: what is this?
#
# jerry: i don't know what i don't know what i think it's a shower to the standing the pat the thing to the story.
#
# jerry: i have to get it at the thing to the cance.
#
# kramer: the store come on the
# ----- diversity: 0.5
# ----- Generating with seed: "ng for me. yeah, i r"
# ng for me. yeah, i really in the stand?
#
# jerry: i can't believe the couch and the shoulder but i was a conversion.
#
# jerry: it was not the father is a steal.
#
# kramer: i'll be something on the time.
#
# kramer: what is it?
#
# elaine: hey, i gotta see him, i don't know what would have a come anything?
#
# jerry: i'm supposed to leave that i can't have to get each of the side of the book deal?
#
# jerry: i like a call down.
# ----- diversity: 1.0
# ----- Generating with seed: "ng for me. yeah, i r"
# ng for me. yeah, i remember you about. nothing. thanks as i am in anyhim, so.
#
# hotty: i wear schine.
#
# naked shiffer: look awed, then a choopage of her working out there's a meeture, kind told me. it's my bend, clookiatent numbe. huh.
#
# george: "robrtaller-up... i have real forman. i pick up so any life.
#
# elaine: that you just just say you never won't back your humble. the h*huro*hard.
#
# elaine: can hunt ever have
# ----- diversity: 1.2
# ----- Generating with seed: "ng for me. yeah, i r"
# ng for me. yeah, i right. i think it's take the david natt.
#
# jerry: (upually of he cupsing back your back?
#
# elaine: i snaubful nigh. all right. a kind on a botturant on my uals people she came me haafhiam. i a knowse it's svely]
#
# newman: longor holiel. mylanter beanisulcle mying. beapnion, you've got her that came awres, jerry, another witter. i'll fiftt be a coton.
#
# toby: don't go by just mome, a) george look in
#
# Epoch 00017: loss improved from 1.25649 to 1.25378, saving model to weights.hdf5
# Epoch 18/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2464
#
# ----- Generating text after Epoch:  17
# ----- diversity: 0.2
# ----- Generating with seed: "g?
#
# jerry: well, i "
# g?
#
# jerry: well, i got a good the couch and show on the money.
#
# george: well, i want to get to the street of the couple of the says hold of the book on the point of the sen and the seat the couch of the car.
#
# george: well, the store to the shower on the message to the picture to the couch and the point the couple of the sandwass to the most and the seen the street in the back of the seen the store of the word of t
# ----- diversity: 0.5
# ----- Generating with seed: "g?
#
# jerry: well, i "
# g?
#
# jerry: well, i want to get on the better and what was the beath)
#
# george: what about this?
#
# george: i don't know...
#
# george: and i got the chancellows mail out the restaurant work with the police in the hands.
#
# elaine: well, well, i got to get home.
#
# elaine: (still puts on the sen and man and the hair and we were on the bettered with the screen table in the back on the door...
#
# george: the puts the mother
# ----- diversity: 1.0
# ----- Generating with seed: "g?
#
# jerry: well, i "
# g?
#
# jerry: well, i one. george, if it got hime. we're wearn't been so nose's that five lan'.
#
# george: right.
#
# kramer: you--
#
# susan: not money, don't go to the trupe.
#
# george: that's son. i got him.
#
# mdy tos: my more rivet. they got the viscturear?
#
# george: that's everything. whos?
#
# kramer: just so i seen it on up nunkrack, my is going it in important, the sunterells. she's a checks. that wear hume ticket truc
# ----- diversity: 1.2
# ----- Generating with seed: "g?
#
# jerry: well, i "
# g?
#
# jerry: well, i would do might - great money, i'm something, i hasnearque the touti minist. (taphelfs him)
#
# elaine: po, we think epiceller. i toom. if i'm not 'em.
#
# jerry: soive that does?
#
# tina: very oppsy for younarth. why am ipo!gell usuald over see youd doesn't comelyver wearing you to the exiistach him linerahcaroned an ho heres hands to the girline, and noton a ray's degwoom.)
#
# kramer: pointly bad!
#
# mj
#
# Epoch 00018: loss improved from 1.25378 to 1.25131, saving model to weights.hdf5
# Epoch 19/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2449
#
# ----- Generating text after Epoch:  18
# ----- diversity: 0.2
# ----- Generating with seed: "for the front seat a"
# for the front seat and i was a little of my back.
#
# george: you know, i had to get the story.
#
# elaine: you know, i got a good the rest of the way i can't believe the back of me.
#
# elaine: (to george) i got to come on the table.
#
# elaine: i was the movie work and i was a person of the stands of the course and they ask you a little of the hair of the stands of people of the place to the stands of the stands of the sto
# ----- diversity: 0.5
# ----- Generating with seed: "for the front seat a"
# for the front seat and you are really calling is a man in the man the books a ticken of the factle and man is me?
#
# elaine: you know, he was some friend, they're what i was a really who has like that business the george of problems.
#
# kramer: you see he was going to say boys and looks at the little problem in the appreanal.
#
# elaine: what?
#
# george: then you gotta go to see it in the surprist right the clothes.
#
# ela
# ----- diversity: 1.0
# ----- Generating with seed: "for the front seat a"
# for the front seat as you got thisticable of the beslinuttfaster's interestanot.
#
# bod: you were not why daning, phone strecturecative.
#
# elaine: hey!
#
# phone: you're not shoulder, mationeve your car, scose that that's the bamath, sfah...it. something up.
#
# elaine: oh mey corratery, sree knows a lot interndend with a phone?
#
# elaine: this phone's not's great.
#
# denishes to kramer's what i thinks alwhathes doctut of d
# ----- diversity: 1.2
# ----- Generating with seed: "for the front seat a"
# for the front seat and doll pig my number, you know it -you're a hooking up anothers and you're umsmarcoined, i park it. (incouttoon) alrive wasp cry bro"ward single.
#
# george: oh, marst lick off.. is say, usre, so do talk's play lasi, i think you do is, mee a card. susanook,
#
# elaine: no.
#
# kramer: (shouter) day not?
#
# kramer: my liw phone, shry, has like this people for brandale god as well fix. i realize this free
#
# Epoch 00019: loss improved from 1.25131 to 1.24867, saving model to weights.hdf5
# Epoch 20/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2433
#
# ----- Generating text after Epoch:  19
# ----- diversity: 0.2
# ----- Generating with seed: "ly worst than the al"
# ly worst than the all thing and she says the counter.
#
# jerry: you know, i don't know what i do.
#
# jerry: i don't know what i do that show.
#
# jerry: yeah, i don't know.
#
# jerry: yeah, you know, i can tell you to do that show on the starts the starts up the couple of the store to do that thing thing and i can be a second.
#
# jerry: i said the car.
#
# jerry: i don't know.
#
# george: i don't know.
#
# jerry: what are you doi
# ----- diversity: 0.5
# ----- Generating with seed: "ly worst than the al"
# ly worst than the all to really put you doesn't say and she doing to have to call that many sitting any car.
#
# kramer: yeah, i was to do the apersellible of committent.
#
# jerry: they're a car.
#
# jerry: hey we can't made to do it.
#
# kramer: yeah, yeah.
#
# george: i don't know, she was a little could come him.
#
# elaine: yeah, no no, you know what it was the sitch for eats and that and getting to make you and i don't go
# ----- diversity: 1.0
# ----- Generating with seed: "ly worst than the al"
# ly worst than the all guas crots that things replace.
#
# kramer: stay vanestion four bail.
#
# volce, jerry: that's going on that.
#
# kramer: well, i'd like agother of sicking, i'm as here to you we let charot.
#
# elaine: what do you like and i love go anny together out, fundy! oh, you saw you got paying us us his boy.
#
# george: no, no veryonab. seans it and knocesure are and brings. sbet out the stop work, beove's callin
# ----- diversity: 1.2
# ----- Generating with seed: "ly worst than the al"
# ly worst than the alt carebole. !way, mlansiag.
#
# george: maybe jerry is sometwering?
#
# jerry: 'i nnenlant of us.. all right my next for le paying.
#
# george: (andsip)
#
# r
# man: icauling out fire tranps. ywow thanking. then you take them of really howin' that. you, give her in acoummiting yight shake of this?
#
# elaine: there's to do
#
# pholch: and alo go, youre back.'?
#
# clorken: if i are not sreed.
#
# george: daying.
#
#
#
# Epoch 00020: loss improved from 1.24867 to 1.24644, saving model to weights.hdf5
# Epoch 21/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2422
#
# ----- Generating text after Epoch:  20
# ----- diversity: 0.2
# ----- Generating with seed: " anything else?
#
# ge"
#  anything else?
#
# george: what?
#
# kramer: hey, you know, i have a parting and they think you said you got a good thing and they want to get that he was the hair of the condent of the partion of the way to have to get my face and i was the parents of the point of the picture of the condonal parting out of the partion of the condent.
#
# jerry: hey, i have to see how that who have to go to the show that i was the back of
# ----- diversity: 0.5
# ----- Generating with seed: " anything else?
#
# ge"
#  anything else?
#
# george: what?
#
# jerry: come on, i didn't think why hope the parogs that i was the store people make a some true.
#
# jerry: i was the hold look at a street.
#
# elaine: oh, i'll be hold of the care.
#
# elaine: oh no, no, no, i have to have to go to the book how she's not here and the way the bedway?
#
# kramer: alright, all right, i think you see?
#
# elaine: jerry, i got a money.
#
# george: i thought what i
# ----- diversity: 1.0
# ----- Generating with seed: " anything else?
#
# ge"
#  anything else?
#
# george: all right.
#
# elaine: ohhhh, i think you're paleribelt my fatter fan minal stock with you popper, loud on that.
#
# jerry: what are you borris?ly, you don't put it, it's albad ade then what they have boy's will manute.
#
# elaine: his moping car show... pcose! (looks at it of has in: name?
#
# jerry: its little years were gonna eehets for all the comedian ...
#
# kramer: why told my clack some nected
# ----- diversity: 1.2
# ----- Generating with seed: " anything else?
#
# ge"
#  anything else?
#
# george: well leo.
#
# elaine: can't you were you bathroom?
#
# jade: those you kill it?
#
# jerry: hohguctilysping brast this.
#
# aeh useau...this is knowe.s, that elf-cos recitures the seeut i seoumt un, neiphh, one. this is trying lookiyn't h russe of allico.
#
# george: you to see, i know it's pelfining down. in loved on you succk?!! how'llrb. thair afterful turht? you know him? it's saying?
#
# -.okits tha
#
# Epoch 00021: loss improved from 1.24644 to 1.24618, saving model to weights.hdf5
# Epoch 22/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2387
#
# ----- Generating text after Epoch:  21
# ----- diversity: 0.2
# ----- Generating with seed: "e, can you zip me up"
# e, can you zip me up to him.
#
# george: i don't know what they say this to the story.
#
# jerry: hey what's the problem to the story.
#
# george: what are you gonna do?
#
# elaine: i can't see you waiting to the come of the car of the big store of the point to the point to the story.
#
# jerry: i don't know what i can be the back of the common.
#
# jerry: i don't know what i don't know the car come in to the street on the commu
# ----- diversity: 0.5
# ----- Generating with seed: "e, can you zip me up"
# e, can you zip me up and office to talk in the brow.
#
# jerry: it's not and we see a building with shop?
#
# elaine: well, i know what i said she take it?
#
# jerry: i'm sorry it was gonna do that we brought to her with the reparsie of the table.
#
# george: i can't have to be a book and they said something.
#
# elaine: i think it's not kid to the matter to me. the picked on the beef) elaine is should going to be back.
#
# geor
# ----- diversity: 1.0
# ----- Generating with seed: "e, can you zip me up"
# e, can you zip me up to forer machine. (rieht pair to the truce..
#
# jerry: because you gotta do.
#
# frank: wefreen arpotty in town that. then an i later): yeah right! you could stop. and i had to be!
#
# george: so! it w'see he watch out or neyde?
#
# george: i have anything what you go eka to him!
#
# elaine: sorryonator.
#
# newman: i love the ofora!
#
# jerry: it's a corry... lef leves isson times if i'm felling. noh. and we
# ----- diversity: 1.2
# ----- Generating with seed: "e, can you zip me up"
# e, can you zip me upselmits!
#
# heatue: this is takking filuld one cost?
#
# kramer: what, if this whon horr pund somever in. i'm weaking agzing? (holdived think she moved this mailion. bubby)
#
# .nna: oh, turn. ma styman. let me tell braded to seem banges and to work my few pati, iidi' (kramernay) run that.
#
# maya: sure. all issein manu dishause. (emjoring it out at much? and the doing glades to brings on cops toway) al
#
# Epoch 00022: loss improved from 1.24618 to 1.24419, saving model to weights.hdf5
# Epoch 23/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2407
#
# ...
#
# elaine: this is ttan now, they think the og frank on people to coursing. what thing would ignothing the coffee as not about this, but i....
# ----- diversity: 1.2
# ----- Generating with seed: "i. elaine, it's me. "
# i. elaine, it's me. it's sirder)
#
# jerry: you made all this?
#
# george: then date to mister, it have theres) isna-down, what for? you look jerry like im breapthin to every--he can pra a guy about.
#
# elaine: if another one now? my plat yanap.
#
# iptena: well is the vandeal pototing him enk in ts-crart twearroh. i'm ahtat reading food one over. (working) if this roallwaying wrongroty, your mazine menashhagold for that qu
#
# Epoch 00033: loss improved from 1.23392 to 1.23355, saving model to weights.hdf5
# Epoch 34/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2283
#
# ----- Generating text after Epoch:  33
# ----- diversity: 0.2
# ----- Generating with seed: "ou in with it.
#
# kra"
# ou in with it.
#
# kramer: you know what i don't know than the car was and she was good.
#
# jerry: what are you sure?
#
# kramer: you know what i was the book of her of the same friends with the standing in the movie with the party to do the car.
#
# kramer: you know what i want to get a second.
#
# jerry: what do you know what i want to get a second.
#
# jerry: what are you doing?
#
# elaine: yeah, you know what i was the counte
# ----- diversity: 0.5
# ----- Generating with seed: "ou in with it.
#
# kra"
# ou in with it.
#
# kramer: hey what is the friends and the show it and the bathroom.
#
# elaine: (to her contrenner thing the building going on me.
#
# jerry: what do you have your big things to be a charoly the point of the chance.
#
# jerry: he didn't have in here.
#
# elaine: that's not fine.
#
# elaine: you know, she's hand it up everything the surman worked to make that much family salaurant with me.
#
# jerry: (shouting up h
# ----- diversity: 1.0
# ----- Generating with seed: "ou in with it.
#
# kra"
# ou in with it.
#
# kramer: boy. what about my po-doot. (to the life) he's businessom or davidien? did un.
#
# elaine: that's another pased, why voiches the time for i dont move if youh well rememing un three?
#
# kramer: george.
#
# kramer: it's a sawg!
#
# jerry: oh, it shife's everyone runnol lawing nicking to do i'm not conversecteds.
#
# jerry: man. look, you're left.
#
# frank: all right!
#
# lirwn: call a big.
#
# kramer: i was
# ----- diversity: 1.2
# ----- Generating with seed: "ou in with it.
#
# kra"
# ou in with it.
#
# kramer: and any pwoton, you don't want to mred here?
#
# george: i don't ma* knowne
#
# tn.: what is per? finally essuerate. anynght, forgried.
#
# kramer: no. c'mon, she's fintier partman bad get gujans in, but very news went fuw i'll talk to must suap. ow they're scarmant, idcougly buy.
#
# jerry: (umpudped) come or.
#
# ha
# ja
# p
#
#
#
#
#
#
#
#
# [think any trannialer...yk.
#
# sid: owo does i do?
#
# elaine (reasanal mill
#
# Epoch 00034: loss improved from 1.23355 to 1.23265, saving model to weights.hdf5
# Epoch 35/40
# 5425/5425 [==============================] - 24s 5ms/step - loss: 1.2234
#
# ----- Generating text after Epoch:  34
# ----- diversity: 0.2
# ----- Generating with seed: ": kramer?
#
# kramer: "
# : kramer?
#
# kramer: what are you going to take a see it out of a card to the car man starts to the street the steak for the word of the word of the poor to the standing to the see the bably to the story show and i told you a time and i was the show in the word of my show in the guy was the word of the store work of the word of the word so the way to me a stuff of the time is the card of a money to the park to the sho
# ----- diversity: 0.5
# ----- Generating with seed: ": kramer?
#
# kramer: "
# : kramer?
#
# kramer: hey hey, i can meet you.
#
# george: i am going to the man and he was turning to the cap.
#
# jerry: that's a shower to drive.
#
# jerry: well, i got this woman.
#
# george: (as going) no no ..............................................
#
# jerry: why don't you take something a man.
#
# george: why?
#
# george: i'm dead in the friend friend to see the same takes on the poor soup a lot of clother card.
#
# kramer
# ----- diversity: 1.0
# ----- Generating with seed: ": kramer?
#
# kramer: "
# : kramer?
#
# kramer: then what i really hearons. that. runnilinute read ontally?
#
# sfan asondent with someone waves in the own delicious same card. he's actually were isremitic in there, for this story, so gedrancen.
#
# elaine: mambreet. (getheald yightantic is aqullag allemile.
#
# elaine: about the swoppet chicken.
#
# kramer: hurhing you again. (starts would be you move! i make this now, marriadumber? did you be would p
# ----- diversity: 1.2
# ----- Generating with seed: ": kramer?
#
# kramer: "
# : kramer?
#
# kramer: yeah! oh mepfater!..no yah! she's a jacket. i worked that six?
#
# elaine: joe' at your gestirpered?
#
# pid: ah, i keacking ...i mean at the bokers! i happened! yeu, ruspos. i have pray out the word? i call itlant lodd.
#
# elaine: cas thistiry.
#
# jerry: jerry, kofferent for the bublen two paid, he sureting around im my tupain too bag. and gotta at a lotbook) you're it at! take to am indsandman) right.
#
# Epoch 00035: loss improved from 1.23265 to 1.23180, saving model to weights.hdf5
# Epoch 36/40
# 5425/5425 [==============================] - 24s 5ms/step - loss: 1.2306
#
# ----- Generating text after Epoch:  35
# ----- diversity: 0.2
# ----- Generating with seed: "
#
# sid: hey, somebod"
#
#
# sid: hey, somebody were in the store of the car to the story.
#
# george: you know what i don't know what they don't know that the seniced and stops a little with the phone of the point for the story man starts the track.
#
# elaine: (to kramer)
#
# kramer: well, i have to do the phone?
#
# jerry: i don't know what you want to get a little street in the but of the store and i don't know what you know what i was a little t
# ----- diversity: 0.5
# ----- Generating with seed: "
#
# sid: hey, somebod"
#
#
# sid: hey, somebody did you seen the coffee not my fact oned my deal, a way i wanted to come to you.
#
# jerry: (exits) i can't know we seen we have a minutter on the too shoes.
#
# george: who do you go to the denic. you can't invite a sing right from the store.
#
# jerry: get out of my business of the a show money dectalion.
#
# elaine: i saw the but i'm telling me again.
#
# jerry: i don't know, it's a served in the bottl
# ----- diversity: 1.0
# ----- Generating with seed: "
#
# sid: hey, somebod"
#
#
# sid: hey, somebody-yada isn't it on jerry, baby diop from my cract? he saiss to sen game shake. you should see a lide anphote to killed minute. it's a walk jerry and throw and i trying krop on the work?
#
# kramer: oh.
#
# jerry: so i eeze she is that, told it.
#
# kramer: i was in today. lumman be really share in!
#
# kramer: so you know.
#
# jerry: thank you at these he never get yidful it, not me... i love my ball back.
# ----- diversity: 1.2
# ----- Generating with seed: "
#
# sid: hey, somebod"
#
#
# sid: hey, somebody. wouluswindow *hassing we?
#
# kramer: ah! byummer there, what's your aroad
#
# jenna: "how to "in all namer?
#
# kramer: you know.
#
# elaine: look attitiine. us-low.
#
# umpleatio: (swoper) kramer shouts puss wook, air trants.
#
# frank: ahd, i used never tell you, i got mi that his officing. i found you, bellow i'll leak that's mrets of thingss.. she, kiddship is, i should !" you don't make down.
#
# elain
#
# Epoch 00036: loss improved from 1.23180 to 1.23164, saving model to weights.hdf5
# Epoch 37/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2253
#
# ----- Generating text after Epoch:  36
# ----- diversity: 0.2
# ----- Generating with seed: "him )
#
# repairman: s"
# him )
#
# repairman: so what is this?
#
# george: i would be a show on the thing this man thing is a little car.
#
# jerry: yeah, i don't know what you see it a senson and the car man thing and she was this is a starts the point thing thing thing that i can have to talk to the car part of the store starts to the stands and the come one of the standing this is a starts the problem and i was a check of the store thing and th
# ----- diversity: 0.5
# ----- Generating with seed: "him )
#
# repairman: s"
# him )
#
# repairman: so what's why touch anizer could a lot of it is in the george.
#
# jerry: all right, what are you going to think it an entiure in the back and all the way to she had a stands and three this point nose!
#
# elaine: hey, i can't start the friends of the stands and marriaming it in the stought to the best and good move and strange of the phone of the pulling it at night.
#
# jerry: all right.
#
# george: what
# ----- diversity: 1.0
# ----- Generating with seed: "him )
#
# repairman: s"
# him )
#
# repairman: shoot out, oh twest good pland, this nose i'm sonk a woman when living moving pretty...that time.... what is he pleaseby
#
# estelle: i'm packer lifting in all dand.
#
# george: all right. come on out.
#
# posser: oh merris? and like.
#
# elaine: i find you a other generagebling? i'm not chocoon right.
#
# kramer: a all morn of but you know you're racking likes anything..
#
# jerry: i shtring something lover p
# ----- diversity: 1.2
# ----- Generating with seed: "him )
#
# repairman: s"
# him )
#
# repairman: so a sconfrince.
#
# kiccandech: kill if schitchicial four my peant?
#
# pcramon: (carryon what to your packer?
#
# george: rive who's just investing el, uh... now you can hunds?
#
# helen: maybe i'm ..
#
# jerry: whis for good only sighefter she, it's dellinple, waitay. im ruets a point usic out on tick. you'relano bacl, it? in al eal in a break!
#
# oelicend olt jerry?
#
# jerry: excicsting a drved. nemonro. y
#
# Epoch 00037: loss improved from 1.23164 to 1.23136, saving model to weights.hdf5
# Epoch 38/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2251
#
# ----- Generating text after Epoch:  37
# ----- diversity: 0.2
# ----- Generating with seed: " i think i hit my he"
#  i think i hit my head with the point to the store.
#
# elaine: i don't know what i was the baby.
#
# elaine: i don't know what it was a lot of the street of the baby.
#
# elaine: i don't know what i was the baby.
#
# elaine: well, i don't want to be street of the card.
#
# elaine: well i don't want to be a point.
#
# elaine: well, i don't want to be a supposed to get in the baby.
#
# elaine: well i don't know what i was the point
# ----- diversity: 0.5
# ----- Generating with seed: " i think i hit my he"
#  i think i hit my head in the pirce of the but i have a dress one.
#
# elaine: well, everything really got you.
#
# elaine: wait a day?
#
# jerry: what do you know what are you going to get the card of the porents and when you could be a pight and i was going to get and you got to be even the clapen of the bolf of trocia she can work. i want to trame you to the meal?
#
# kramer: i just beausuan a personal of the friend are l
# ----- diversity: 1.0
# ----- Generating with seed: " i think i hit my he"
#  i think i hit my heed! morty?!
#
# elaine: (strongules bad) alriddest pe gigl.
#
# mrs cennciny: i'll start furt on the phone.
#
# elaine: come on. we guese it.
#
# kramer: no. wild you do that?
#
# raba: what's those? problem?
#
# elaine: well you want you us in troublicing in a saled clchin if i smilo elaine is the dulise looking of filldes putting of marching.
#
# jerry: so.
#
# herable: it's pan.
#
# estegg out man, the consistly
# ----- diversity: 1.2
# ----- Generating with seed: " i think i hit my he"
#  i think i hit my heat try muddwill jignoed krucand you know much, id won't retic. baby!
#
# elaine: i'm great wonderward apartment]
#
# elaine: jerry you go tracked with tonibef erster. not drin't rissphones, would, walking a elasy, basters?
#
# kramer: what's the girl one uh, (to banial) not intley. a bzze that daucagia... cleans strecefes who at perfecot pasy, i tom it up laving.) no vrain! itfifing uh---
#
# kramer: well
#
# Epoch 00038: loss improved from 1.23136 to 1.23115, saving model to weights.hdf5
# Epoch 39/40
# 5425/5425 [==============================] - 25s 5ms/step - loss: 1.2266
#
# ----- Generating text after Epoch:  38
# ----- diversity: 0.2
# ----- Generating with seed: " green, dick houser,"
#  green, dick houser, the car one and he was the time is a little to the tickets and the book of the book of the point of the table.
#
# elaine: (to the standing) i don't know what you know what i got a terrible of the book of the door the good story to the book of the story to the play of the forers on the door the face of the friend and i have to go to the thing than you could be a lot of the bathroom.
#
# jerry: i don'
# ----- diversity: 0.5
# ----- Generating with seed: " green, dick houser,"
#  green, dick houser, it's the problem in the book of change.
#
# elaine: really.
#
# jerry: you seel anything and it was something to the tousand of there with the seeman.
#
# george: (pause) what is the way it?
#
# kramer: yeah. what do you think?
#
# kramer: you know what it was a book?
#
# george: i'm sorry.
#
# jerry: what is this?
#
# jerry: (they were the couch)
#
# jerry: (strains the thousand.
#
# elaine: yeah, i could do that j
# ----- diversity: 1.0
# ----- Generating with seed: " green, dick houser,"
#  green, dick houser, a lot extent on this.
#
# clerk: runding.
#
# elaine: hey!
#
# elaine: yeah!
#
# george: jerry, you know this you. you mean...
#
# banban: oh, i'm late your off! ahh, yeah.
#
# kramer: no!
#
# jerry: (tables) well i'm up, kid!!!
#
# elaine: it.
#
# woman: (stmands) yes, i'm in yau?
#
# jerry: i'll man something. it has at this handic of a clean to sing to last in every look lame. (they don't just go. ...ho hellems a
# ----- diversity: 1.2
# ----- Generating with seed: " green, dick houser,"
#  green, dick houser, that gogs out at sirarising me...an compraap! lom oncesle? so john andn't triclys hanp, russiog.
#
# deena: oldect any---hoty salazes  issting.
#
# kramer: what!!..
#
# newvatecsiv: yes lecanic stelling?
#
# mrs.. go i-lappedicments. uh... allitting my door, i wanted to when gonna do this...it you wants. i'c--up innymys. ...- alrights.
#
# george: i'm favor friends.
#
# kramer: well, she itakeation invlunica
#
# Epoch 00039: loss improved from 1.23115 to 1.23051, saving model to weights.hdf5
# Epoch 40/40
# 5425/5425 [==============================] - 24s 4ms/step - loss: 1.2227
#
# ----- Generating text after Epoch:  39
# ----- diversity: 0.2
# ----- Generating with seed: "y for them.
#
# kramer"
# y for them.
#
# kramer: what about that?
#
# jerry: what is that?
#
# kramer: what are you doing?
#
# george: what do you think?
#
# jerry: what are you gonna do that to the part of the stands of the starts to the friends and the stands of the start and starts the real for the face and the word on the track and the way to the face and the table.
#
# jerry: what are you supposed to be a bubble.
#
# jerry: what do you think it was t
# ----- diversity: 0.5
# ----- Generating with seed: "y for them.
#
# kramer"
# y for them.
#
# kramer: well, i have to let me got the only dollars.
#
# jerry: yeah, i can have to be solgrand with the phone of the busy.
#
# jerry: what do you think you never have to go for her and because what i want to go.
#
# jerry: well, what is this?
#
# jerry: i don't think you know what i just want to sparking hands and compan't.
#
# jerry: (to jerry)
#
# jerry: what?
#
# jerry: oh, hey, jerry, should you don't foll that
# ----- diversity: 1.0
# ----- Generating with seed: "y for them.
#
# kramer"
# y for them.
#
# kramer: come confuse by type.
#
# elaine: hey. talk to him.....
#
# jerry: and my sneaking out in the new.
#
# jerry: "oun "hey bonggg dover guy. hes the for an lett. i empletselling up about these the lightating?
#
# bur: i'm sorry!
#
# george: was one.
#
# elaine: (seoseth to a little doct wiered.
#
# jerry: get that talk more packer check. (levely nice work lem. but because i don't know?
#
# jerry: i'm disgush each
# ----- diversity: 1.2
# ----- Generating with seed: "y for them.
#
# kramer"
# y for them.
#
# kramer: why?
#
# kramer: because your tiuble.kimment, but?
#
# newman: that 'sman or...
#
# pitt: which an in food on george! in my going. .... how dr?
#
# kramer: mr! (che stome kramer) ... but hel, so j-mailmon with mentment!
#
# rge": yes, the joffwo two jokeful. my first wallet signity's hug? i don't told peckerge ... i, this nina, we'll go va-rust! you let that wearin' (mughteing) 'lffat him... i knoy.
#
# su)
#
# Epoch 00040: loss improved from 1.23051 to 1.22987, saving model to weights.hdf5

# %%
def generate_text(length, diversity):
    # Get random starting text
    start_index = random.randint(0, len(text) - max_length - 1)
  
    # Defining the generated text
    generated = ''
    sentence = text[start_index: start_index + max_length]
    generated += sentence
  
    # Generating new text of given length
    for i in range(length):
  
            # Initializing the predicition vector
            x_pred = np.zeros((1, max_length, len(vocabulary)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_to_indices[char]] = 1.
  
            # Making the predicitons
            preds = model.predict(x_pred, verbose = 0)[0]
  
            # Getting the index of the next most probable index
            next_index = sample_index(preds, diversity)
  
            # Getting the most probable next character using the mapping built
            next_char = indices_to_char[next_index]
  
            # Generating new text
            generated += next_char
            sentence = sentence[1:] + next_char
    return generated

# %%
print(generate_text(50, 1.0))
# Out:
# the moron in the blubed fro.
# kramer: What are you like the push thent.

# %% [markdown]
# ## Clean up the code
