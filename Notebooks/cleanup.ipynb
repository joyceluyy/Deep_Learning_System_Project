# %%
import os
import pickle
import numpy as np
import pandas as pd
import csv
import sys
import nltk

# %% [markdown]
# ### Data Preprocessing

# %%
def load_data(path):
    """
    Load Dataset from File
    """
    input_file = os.path.join(path)
    with open(input_file, "r") as f:
        data = f.read()

    return data

def preprocess_and_save_data(dataset_path, token_lookup, create_lookup_tables):
    """
    Preprocess Text Data
    """
    text = load_data(dataset_path)
    
    # Ignore notice, since we don't use it for analysing the data
    text = text[81:]

    token_dict = token_lookup()
    for key, token in token_dict.items():
        text = text.replace(key, ' {} '.format(token))

    text = text.lower()
    text = text.split()

    vocab_to_int, int_to_vocab = create_lookup_tables(text + list(SPECIAL_WORDS.values()))
    int_text = [vocab_to_int[word] for word in text]
    pickle.dump((int_text, vocab_to_int, int_to_vocab, token_dict), open('preprocess.p', 'wb'))

def load_preprocess():
    """
    Load the Preprocessed Training data and return them in batches of <batch_size> or less
    """
    return pickle.load(open('preprocess.p', mode='rb'))

# %%
scripts = pd.read_csv('./data/scripts.csv', index_col=0)
scripts.head()
# Out:
#   Character                                           Dialogue  EpisodeNo  \
# 0     JERRY  Do you know what this is all about? Do you kno...        1.0
# 1     JERRY  (pointing at Georges shirt) See, to me, that b...        1.0
# 2    GEORGE                                   Are you through?        1.0
# 3     JERRY             You do of course try on, when you buy?        1.0
# 4    GEORGE  Yes, it was purple, I liked it, I dont actuall...        1.0
#
#      SEID  Season
# 0  S01E01     1.0
# 1  S01E01     1.0
# 2  S01E01     1.0
# 3  S01E01     1.0
# 4  S01E01     1.0

# %%
scripts[['Character', 'Dialogue']].groupby(['Character']).count().sort_values(by='Dialogue',ascending=False).head(10)
# Out:
#            Dialogue
# Character
# JERRY         14786
# GEORGE         9708
# ELAINE         7983
# KRAMER         6664
# NEWMAN          640
# MORTY           505
# HELEN           471
# FRANK           436
# SUSAN           379
# [Setting        293

# %%
def convert_to_role_dialogue(r):
    return r[0].lower()+": "+ r[1]

# %%
scripts['char_dial'] = scripts['Character'].str.lower()+': '+scripts['Dialogue']
scripts.head()
# Out:
#   Character                                           Dialogue  EpisodeNo  \
# 0     JERRY  Do you know what this is all about? Do you kno...        1.0
# 1     JERRY  (pointing at Georges shirt) See, to me, that b...        1.0
# 2    GEORGE                                   Are you through?        1.0
# 3     JERRY             You do of course try on, when you buy?        1.0
# 4    GEORGE  Yes, it was purple, I liked it, I dont actuall...        1.0
#
#      SEID  Season                                          char_dial
# 0  S01E01     1.0  jerry: Do you know what this is all about? Do ...
# 1  S01E01     1.0  jerry: (pointing at Georges shirt) See, to me,...
# 2  S01E01     1.0                           george: Are you through?
# 3  S01E01     1.0      jerry: You do of course try on, when you buy?
# 4  S01E01     1.0  george: Yes, it was purple, I liked it, I dont...

# %%
scripts['answer_character'] = scripts['Character'].shift(-1)
scripts.head()
# Out:
#   Character                                           Dialogue  EpisodeNo  \
# 0     JERRY  Do you know what this is all about? Do you kno...        1.0
# 1     JERRY  (pointing at Georges shirt) See, to me, that b...        1.0
# 2    GEORGE                                   Are you through?        1.0
# 3     JERRY             You do of course try on, when you buy?        1.0
# 4    GEORGE  Yes, it was purple, I liked it, I dont actuall...        1.0
#
#      SEID  Season                                          char_dial  \
# 0  S01E01     1.0  jerry: Do you know what this is all about? Do ...
# 1  S01E01     1.0  jerry: (pointing at Georges shirt) See, to me,...
# 2  S01E01     1.0                           george: Are you through?
# 3  S01E01     1.0      jerry: You do of course try on, when you buy?
# 4  S01E01     1.0  george: Yes, it was purple, I liked it, I dont...
#
#   answer_character
# 0            JERRY
# 1           GEORGE
# 2            JERRY
# 3           GEORGE
# 4            JERRY

# %%
summary = scripts[['Character', 'answer_character', 'Dialogue']].groupby(['Character', 'answer_character']).count().reset_index()

# %%
summary.head()
# Out:
#                                            Character     answer_character  \
# 0                                           "SALMAN"  BETSY (to Aunt May)
# 1                                           "SALMAN"               KRAMER
# 2                    "SALMAN" (shakes Kramer's hand)               KRAMER
# 3  % A night at the Improv. Jerry receives some d...                JERRY
# 4  % Apparently, a movie that can be interpreted ...               KRAMER
#
#    Dialogue
# 0         1
# 1         2
# 2         1
# 3         1
# 4         1

# %%
df = summary[summary.Character.isin(['JERRY', 'GEORGE', 'ELAINE', 'KRAMER'])][summary.answer_character.isin(['JERRY', 'GEORGE', 'ELAINE', 'KRAMER'])]
df
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      Character answer_character  Dialogue
# 946     ELAINE           ELAINE       204
# 974     ELAINE           GEORGE      1123
# 1027    ELAINE            JERRY      3298
# 1071    ELAINE           KRAMER       889
# 1784    GEORGE           ELAINE      1134
# 1821    GEORGE           GEORGE       265
# 1864    GEORGE            JERRY      4287
# 1908    GEORGE           KRAMER       948
# 2752     JERRY           ELAINE      3262
# 2805     JERRY           GEORGE      4278
# 2884     JERRY            JERRY       550
# 2932     JERRY           KRAMER      2736
# 3703    KRAMER           ELAINE       902
# 3739    KRAMER           GEORGE       955
# 3785    KRAMER            JERRY      2612
# 3834    KRAMER           KRAMER       256

# %%
all_d = df[['Character', 'Dialogue']].groupby(['Character']).sum().reset_index()
all_d.head()
# Out:
#   Character  Dialogue
# 0    ELAINE      5514
# 1    GEORGE      6634
# 2     JERRY     10826
# 3    KRAMER      4725

# %%
prob = pd.merge(all_d, df, on=['Character'])
prob
# Out:
#    Character  Dialogue_x answer_character  Dialogue_y
# 0     ELAINE        5514           ELAINE         204
# 1     ELAINE        5514           GEORGE        1123
# 2     ELAINE        5514            JERRY        3298
# 3     ELAINE        5514           KRAMER         889
# 4     GEORGE        6634           ELAINE        1134
# 5     GEORGE        6634           GEORGE         265
# 6     GEORGE        6634            JERRY        4287
# 7     GEORGE        6634           KRAMER         948
# 8      JERRY       10826           ELAINE        3262
# 9      JERRY       10826           GEORGE        4278
# 10     JERRY       10826            JERRY         550
# 11     JERRY       10826           KRAMER        2736
# 12    KRAMER        4725           ELAINE         902
# 13    KRAMER        4725           GEORGE         955
# 14    KRAMER        4725            JERRY        2612
# 15    KRAMER        4725           KRAMER         256

# %%
prob['probability'] = prob['Dialogue_y']*1.0/prob['Dialogue_x']
prob
# Out:
#    Character  Dialogue_x answer_character  Dialogue_y  probability
# 0     ELAINE        5514           ELAINE         204     0.036997
# 1     ELAINE        5514           GEORGE        1123     0.203663
# 2     ELAINE        5514            JERRY        3298     0.598114
# 3     ELAINE        5514           KRAMER         889     0.161226
# 4     GEORGE        6634           ELAINE        1134     0.170938
# 5     GEORGE        6634           GEORGE         265     0.039946
# 6     GEORGE        6634            JERRY        4287     0.646216
# 7     GEORGE        6634           KRAMER         948     0.142900
# 8      JERRY       10826           ELAINE        3262     0.301312
# 9      JERRY       10826           GEORGE        4278     0.395160
# 10     JERRY       10826            JERRY         550     0.050804
# 11     JERRY       10826           KRAMER        2736     0.252725
# 12    KRAMER        4725           ELAINE         902     0.190899
# 13    KRAMER        4725           GEORGE         955     0.202116
# 14    KRAMER        4725            JERRY        2612     0.552804
# 15    KRAMER        4725           KRAMER         256     0.054180

# %%
for i in ['jerry', 'george', 'elaine', 'kramer']:
    temp = scripts[scripts.Character == i.upper()]
    temp[['char_dial']].to_csv(r'./data/{i}_script.txt'.format(i=i), header=None, index=None, sep='\n', mode='a')

# %%
csv.field_size_limit(sys.maxsize)

episode = 3
line_text = 2
speaker = 1
d = {}

name = "./data/scripts.csv"
# train_speaker = open("./data/train.txt", "w")
# test_speaker = open("./data/test.txt", "w")
# dev_speaker = open("./data/dev.es", "w")
train_jerry = open("./data/train.txt", "w")
test_jerry = open("./data/test.txt", "w")
dev_jerry = open("./data/dev.txt", "w")

f = open(name)

reader = csv.reader(f)
next(reader)
prevRow = next(reader)

# speaker_vocab = {"<pad>": 0, "<s>": 1, "</s>": 2, "<unk>": 3}
jerry_vocab = {"<pad>": 0, "<s>": 1, "</s>": 2, "<unk>": 3, '<PAD>': 4}
data = {"src_word2id": speaker_vocab, "tgt_word2id": jerry_vocab}
speaker_count = 1
jerry_count = 1

for currRow in reader:
    if currRow[speaker] == "JERRY" and prevRow[episode] == currRow[episode]:
        if int(float(currRow[episode])) <= 15:
#             train_speaker.write(prevRow[line_text] + "\n")
            train_jerry.write(currRow[line_text] + "\n")
        elif int(float(currRow[episode])) <= 19:
#             test_speaker.write(prevRow[line_text] + "\n")
            test_jerry.write(currRow[line_text] + "\n")
        else:
#             dev_speaker.write(prevRow[line_text] + "\n")
            dev_jerry.write(currRow[line_text] + "\n")
    for word in prevRow[line_text].split(" "):
        if word not in speaker_vocab.keys():
            speaker_vocab[word] = speaker_count
            speaker_count += 1
    for word in currRow[line_text].split(" "):
        if word not in jerry_vocab.keys():
            jerry_vocab[word] = jerry_count
            jerry_count += 1
    prevRow = currRow

# %% [markdown]
# ## Training Process

# %%
# data_dir = './data/Seinfeld_Scripts.txt'
# data_dir = './data/elaine_script.txt'
data_dir = './data/train.txt'
print(data_dir)
# Out:
# ./data/train.txt

# %%
text = load_data(data_dir)

# %%
view_line_range = (30, 50)

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in text.split()})))

lines = text.split('\n')
print('Number of lines: {}'.format(len(lines)))
word_count_line = [len(line.split()) for line in lines]
print('Average number of words in each line: {}'.format(np.average(word_count_line)))

print()
print('The lines {} to {}:'.format(*view_line_range))
print('\n'.join(text.split('\n')[view_line_range[0]:view_line_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 15631
# Number of lines: 10240
# Average number of words in each line: 10.0705078125
#
# The lines 30 to 50:
# This is insane. You know, I dont even know where shes staying! She, shes not gonna call me, this is unbelievable.
# No no no, dont interrupt the cycle. The machine is working, it, it knows what its doing. Just let it finish.
# You, you cant overdry.
# Same as you cant overwet. You see, once something is wet, its wet. Same thing with death. Like once you die youre dead, right? Lets say you drop dead and I shoot you. Youre not gonna die again, youre already dead. You cant overdie, you cant overdry.
# How could she not tell me where she was staying?
# Laundry day is the only exciting day in the life of clothes. It is...yknow, think about it. The washing machine is the nightclub of clothes. You know, its dark, theres bubbles happening, theyre all kinda dancing around in there- shirt grabs the underwear, Cmon babe, lets go. You come by, you open up the lid and theyll- (stiffens up, as the clothes) Socks are the most amazing article of clothing. They hate their lives, theyre in the shoes with stinky feet, the boring drawers. The dryer is their only chance to escape and they all know it. They knew a escape from the dryer. They plan it in the hamper the night before, Tomorrow, the dryer, Im goin. You wait here! The dryer door swings open and the sock is waiting up against the side wall. He hopes you dont see him and then he goes down the road. They get buttons sewn on their faces, join a puppet show. So theyre showing me on television the detergent for getting out bloodstains. Is this a violent image to anybody? Bloodstains? I mean, come on, you got a T-shirt with bloodstains all over it, maybe laundry isnt your biggest problem right now. You gotta get the harpoon out your chest first.
# (answering, quickly) If you know what happened in the Met game, dont say anything, I taped it, hello. Yeah, no, Im sorry, you have the wrong number. Yeah, no
# (to the door) Yeah?
# (to Kessler) Yeah. (to the phone) Yeah, people do move. Have you ever seen the big trucks out on the street? Yeah, no problem.
# (upset) Ohhhh, what are you doing? Kessler, its a tape! I taped the game, its one oclock in the morning! I avoided human contact all night to watch this.
# Meat? I dont, I dont know, go... hunt! (Kessler opens the refrigerator and sticks his head in.) Well what happened in the game anyway?
# (cynical) Yeah you almost went to the game. You havent been out of the building in ten years!
# No.
# Yeah, yeah...you can have it tomorrow.
# No, its okay now, that, that girl is not comin. Uh, I misread the whole thing.
# I dont think so.
# That close, huh?
# Hello...Oh, hi, Laura.
# (to the phone) No believe me, Im always up at this hour. How are you?... Great... Sure... What time does the plane get in?... I got my friend George to take me...
# No, its, its just my neighbour... Um... Yeah, I got it. (Jerry takes a pencil and a cereal box to write on.) Ten-fifteen... No, dont be silly, go ahead and ask... Yeah, sure... Okay, great, no no, its no trouble at all... Ill see you tomorrow... Great, bye. (He hangs up the phone; to Kessler) I dont believe it. That was her. She wants to stay here!

# %%
def create_lookup_tables(text):
    """
    Create lookup tables for vocabulary
    :param text: The text of tv scripts split into words
    :return: A tuple of dicts (vocab_to_int, int_to_vocab)
    """
    chars = sorted(list(set(text))) # getting all unique chars
    print('total chars: ', len(chars))
    char_indices = dict((c, i) for i, c in enumerate(chars))
    indices_char = dict((i, c) for i, c in enumerate(chars))
    return chars, char_indices, indices_char

# %%
def token_lookup():
    """
    Generate a dict to turn punctuation into a token.
    :return: Tokenized dictionary where the key is the punctuation and the value is the token
    """
    return {
        '.': '||Period||',
        ',': '||Comma||',
        '"': '||Quotation_Mark||',
        ';': '||Semicolon||',
        '!': '||Exclamation_Mark||',
        '?': '||Question_Mark||',
        '(': '||Left_Parentheses||',
        ')': '||Right_Parentheses||',
        '-': '||Dash||',
        '\n': '||Return||'
        }

# %%
SPECIAL_WORDS = {'PADDING': '<PAD>'}

# %%
vocabulary, char_to_indices, indices_to_char = create_lookup_tables(text)
# Out:
# total chars:  87

# %%
max_length = 20
steps = 5
sentences = []
next_chars = []
for i in range(0, len(text) - max_length, steps):
    sentences.append(text[i: i + max_length])
    next_chars.append(text[i + max_length])
      
# Hot encoding each character into a boolean vector
  
# Initializing a matrix of boolean vectors with each column representing
# the hot encoded representation of the character
X = np.zeros((len(sentences), max_length, len(vocabulary)), dtype = np.bool)
y = np.zeros((len(sentences), len(vocabulary)), dtype = np.bool)
  
# Placing the value 1 at the appropriate position for each vector
# to complete the hot-encoding process
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_to_indices[char]] = 1
        y[i, char_to_indices[next_chars[i]]] = 1

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
  
import numpy as np
import tensorflow as tf
  
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM, GRU
  
from keras.optimizers import RMSprop, Adam
  
from keras.callbacks import LambdaCallback
from keras.callbacks import ModelCheckpoint
from keras.callbacks import ReduceLROnPlateau
from keras.metrics import categorical_accuracy
import random
import sys
# Out:
# Using TensorFlow backend.

# %%
# Helper function to sample an index from a probability array
def sample_index(preds, temperature = 1.0):
# temperature determines the freedom the function has when generating text
  
    # Converting the predictions vector into a numpy array
    preds = np.asarray(preds).astype('float64')
  
    # Normalizing the predicitons array
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
  
    # The main sampling step. Creates an array of probablities signifying
    # the probability of each character to be the next character in the 
    # generated text
    probas = np.random.multinomial(1, preds, 1)
  
    # Returning the character with maximum probability to be the next character
    # in the generated text
    return np.argmax(probas)


# Helper function to generate text after the end of each epoch
def on_epoch_end(epoch, logs):
    print()
    print('----- Generating text after Epoch: % d' % epoch)
  
    # Choosing a random starting index for the text generation
    start_index = random.randint(0, len(text) - max_length - 1)
  
    # Sampling for different values of diversity
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)
  
        generated = ''
  
        # Seed sentence
        sentence = text[start_index: start_index + max_length]
  
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)
  
        for i in range(400):
            # Initializing the predicitons vector
            x_pred = np.zeros((1, max_length, len(vocabulary)))
  
            for t, char in enumerate(sentence):
                x_pred[0, t, char_to_indices[char]] = 1.
  
            # Making the predictions for the next character
            preds = model.predict(x_pred, verbose = 0)[0]
  
            # Getting the index of the most probable next character
            next_index = sample_index(preds, diversity)
  
            # Getting the most probable next character using the mapping built
            next_char = indices_to_char[next_index]
  
            # Building the generated text
            generated += next_char
            sentence = sentence[1:] + next_char
  
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
        
def GRU_model(max_length, vocabulary):
    learning_rate = 0.01
    model = Sequential()
    # Defining the cell type
    model.add(GRU(128, input_shape =(max_length, len(vocabulary))))

    # Defining the densely connected Neural Network layer
    model.add(Dense(len(vocabulary)))

    # Defining the activation function for the cell
    model.add(Activation('softmax'))

    # Defining the optimizing function
#     optimizer = Adam(lr=learning_rate)
    # Defining the optimizing function
    optimizer = RMSprop(lr = learning_rate)
    
    # Configuring the model for training
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[categorical_accuracy])
    return model

# %%
character = 'jerry'
print_callback = LambdaCallback(on_epoch_end = on_epoch_end)
filepath = "weights_{c}.hdf5".format(c=character)
checkpoint = ModelCheckpoint(filepath, monitor ='loss',verbose = 1, save_best_only = True,mode ='min')
reduce_alpha = ReduceLROnPlateau(monitor ='loss', factor = 0.2, patience = 1, min_lr = 0.001)
callbacks = [print_callback, checkpoint, reduce_alpha]

model = GRU_model(max_length, vocabulary)
model.fit(X, y, batch_size = 128, epochs = 40, callbacks = callbacks)
# Out:
# Epoch 1/40
# 851/851 [==============================] - 6s 6ms/step - loss: 2.3341 - categorical_accuracy: 0.3591
#
# ----- Generating text after Epoch:  0
# ----- diversity: 0.2
# ----- Generating with seed: "ke I don't even know"
# ke I don't even know what is they cares and to she was the mant to my on they really want to he don't know what to you don't know what is they car to you don't know what to you don't know what in they want to you not to be they really arame.
# Now.
# Hey, you don't know.
# I don't know what and they really and they really and you don't know what are you don't know what in they want to my waster they cares they bett to she
# ----- diversity: 0.5
# ----- Generating with seed: "ke I don't even know"
# ke I don't even know.
# Well you don't know and to do you didn't pitting to in your and to her come on they radiry core in of hare
# and bad to she was has buck.
# (one there)
# Hey, you dennd that and they care and they never on my arry back to you bat to now carsto ma.
# Hey, you don't know are you don't know hare do yin.
# Hey. I'll dend they to sary in that what in they right and they cant in and they) Hey don't know.
# They n
# ----- diversity: 1.0
# ----- Generating with seed: "ke I don't even know"
# ke I don't even know.
# Jey, I det'ver in't veny they overy, (Jeen looked of rumend.
# Hey, you dom'try, what andessta yo".
# Hathank would remer carces Cicourse yea.
# I days ublick no froumer.
# Oh aw ulbow.
# Well thah,. It's turk learsed Gadrywe warty
# sudd, me these?
# You have they wauind of they right, Bed you rave wretorabbufled to upmobleab for?
# Wath bid Oh
# What was myy do ne dand de...
# Knamer) Hdy anbat. Cheyd just to sou
# ----- diversity: 1.2
# ----- Generating with seed: "ke I don't even know"
# ke I don't even know. he?
# kech wear jos to Kramer?
# Wa'd flay.
# Hey...w hem you know! (Threwingk, they?
# You cour alrbo aisonmied old cbut, he Sond you bett they sanded nom In's gettict feemach? uh-- jokedch.
# (What hguck too.
# (voubll) 'Gchiom?
# Whey? What. He?
# , hhat isged horg
# ?
# .. Im for!"They'sJan.
# Hey. I'll garnd mablames.
# Hey .duySy, that a wait ughan watte.
# it's tox heme mastake) .!
# Sour.
# "I'll get tirk Degker.
# ona
#
# Epoch 00001: loss improved from inf to 2.05040, saving model to weights_jerry.hdf5
# Epoch 2/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.7541 - categorical_accuracy: 0.4848
#
# ----- Generating text after Epoch:  1
# ----- diversity: 0.2
# ----- Generating with seed: "an. You're not getti"
# an. You're not getting that some it. There's the chand in the car that his man in that come on the come conciced in the come on the chand in the me thing. There's the come on the chan come on the me. Thanks the come on of the chick. That's not it. There's the ching and that with the come on the come on the man the come on the checked and the chicked in the chome in the come on the becalle come on the come on the come
# ----- diversity: 0.5
# ----- Generating with seed: "an. You're not getti"
# an. You're not getting that bice? Well what and Elaine just bectine me ther opening on table on the ling in the wand up it time that tinch of the bailt.
# That's on perring on that with that what make and that some on me like this pittle with her one on, that sound that time the chick. Son't know what comelon, you love that buck it of up times. There's it. Don't know that what specond. Thanks me me his of the colleal a
# ----- diversity: 1.0
# ----- Generating with seed: "an. You're not getti"
# an. You're not getting your bullly, pot come liWh hid it?
# (Puch it) JJuch and gift, us("Ot, there's a probs, abuiderugcon. votervon like mone right undandiopp oud...
# What's not hight ist, ReOHly from just muthing on leal is what amo? No what. doned or micle. Aw you're stell it. WhereKre'lpo light his right trace)
# Yeah, that I go-nah, its left joP.
# Thats, creally'll viwalle. Who encar its thing.
# Nunder. (bat thembopin
# ----- diversity: 1.2
# ----- Generating with seed: "an. You're not getti"
# an. You're not getting on thanky, okeat thourrral) Whach guys belapurs to Ching..
# J'ry leal Sesxp) Yeah, hits other git comding oup offeal. . . It comford?
# No. and yuns
# but that vind. Coscher? Oh yoO nur off righa juybs and mn a plane pontut osen tablo? Hz. Ligth) Rela yon ancel hef did peolleth. I can't onc by hundredes? Will have agly) Thaurlen timo
# I remutin' mumaf Of A-(Geomer, DL, him?
# KraGe uver home... qued's
#
# Epoch 00002: loss improved from 2.05040 to 1.74102, saving model to weights_jerry.hdf5
# Epoch 3/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.6497 - categorical_accuracy: 0.5103
#
# ----- Generating text after Epoch:  2
# ----- diversity: 0.2
# ----- Generating with seed: "robably in Pakistan "
# robably in Pakistan believe for her some confees and he posed to be a bot the come on this coup and and his for her some sicked and pooked to the countion her here for her on the couper confees and he conding any to the coupe on the coupe this with the couse confee on the couple and for her some confee cond of for her some with the couple of the count confees and he conding and he conding a book at the couper come on
# ----- diversity: 0.5
# ----- Generating with seed: "robably in Pakistan "
# robably in Pakistan beciod?
# Bloys.
# Well you wantably to this whated you conted the food to the come one to the one of this call me in course concite fives. (and on sex) The hand of my to do this hes good of to the woman bush of sourded for here! Well you do the convie of a pechion and show is for some be he for going to the concter and convis?
# The way hangs count her the for should confee poursed he soust and this co
# ----- diversity: 1.0
# ----- Generating with seed: "robably in Pakistan "
# robably in Pakistan workat! Suse you like make! ...key's we fauld se diep.
# Shis wvenkends.
# Well?
# Well I even wentione elce frinits timostions. The (pigeding he conkediatify to she?
# Yeah, 'll to this. He'll at you, his con peticial. TFin, whal do this his did to he was for af (AHKa! fokaying a. (Stounding Ted) A't some How you to supposed dit um. Back fove confe?
# Why in out.
# We'd see his come one like!
# So shake!) Goos
# ----- diversity: 1.2
# ----- Generating with seed: "robably in Pakistan "
# robably in Pakistan Chidafe, bractedby weel suptoliat? He like hes beure. rogi!!! fom initediess.
# Sfe, i time, sure allie a, vecle conns) All still of he pefundine Ecaines. nthilled. You know hanteW byed raled his bug.!
# Oo, heat, snst crood I severy, Caul again. You knoI had yoded is fovion olis. Is it ins good walked) foney me monex, from to do be?
# So fop to me in, Freffaint. (hang) Why?d?
# CYou!
# Whe see too' you, fo
#
# Epoch 00003: loss improved from 1.74102 to 1.65708, saving model to weights_jerry.hdf5
# Epoch 4/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.5906 - categorical_accuracy: 0.5269
#
# ----- Generating text after Epoch:  3
# ----- diversity: 0.2
# ----- Generating with seed: "et, it just means he"
# et, it just means here.
# I don't know what the really shook and the roomat the ond of the one of the outson look of the one of the one of the outson out of the one and hand the only the parts on the parts the one of the only the parts of the one of the one of the one of the onlook of the one the parts of the parents the way have the only the parts of the one of the one of the one of the one of the only the parent with
# ----- diversity: 0.5
# ----- Generating with seed: "et, it just means he"
# et, it just means here way that stoper and have the conticiot like around the hand the concervarall but the whate errece and have you.
# Yeah.
# Yeah.
# What dad you do live the one of the onger some for a get him back to me.
# What do you a the hape and it.
# Hey, I thought I don't know it was not the one it won't the count the part the to shook of her.
# Well, I got the sare out the only on the really been beractle the pause t
# ----- diversity: 1.0
# ----- Generating with seed: "et, it just means he"
# et, it just means heart Mashall way, dif, love Nems back the by treybedl. Nither....
# You know, don't not on harban callans meding of the back somersow in ture we reedlad early?
# Yas nepred lour.
# She?
# Ye.
# Ah, George.
# Really?
# Shows Chunpurnate?
# He well I got have gonna bolivent? I'm to knothing that.
# I don't put see oh.
# Rake.
# Hey, Ball not but the Kramer.
# How...
# Huwer....
# He the kink with me mortecing..
# A -Pille? Tha vo
# ----- diversity: 1.2
# ----- Generating with seed: "et, it just means he"
# et, it just means here ohe.
# Will. Mmi shoo?
# Youll call doos?
# Gw, Take.
# Don't go you and Raguts. Bakenusted George sto going to with not shit have foil ball pat too belock you?
# Shill liftle of couplalf
# Nuw?
# I know what do.
# Yiday.
# Y ane't netws Kramer by I'dly wentible.
# Well, Im really hure have to really the dobard bupine ruevent sta tellimeralingth. A rementiod.. strosbioure..
# Relima, Taklo thiself empre feeling and
#
# Epoch 00004: loss improved from 1.65708 to 1.60939, saving model to weights_jerry.hdf5
# Epoch 5/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.5580 - categorical_accuracy: 0.5361
#
# ----- Generating text after Epoch:  4
# ----- diversity: 0.2
# ----- Generating with seed: ".
# All right, I'm sor"
# .
# All right, I'm sorry what the could with the superssand and hand about the cook of the conker of here.
# I got a coptate the cond.
# I don't know what the could bell me and her had and I got a coperson?
# I think I got the coperrout.
# It's a copering of the hold about the cong.
# I don't know what that what doesn't got the could bell a contersorrour.
# You don't know what the could bell the could been and well not it was the
# ----- diversity: 0.5
# ----- Generating with seed: ".
# All right, I'm sor"
# .
# All right, I'm sorry not going to does the places the one letting was gonna gotter?
# I cant way a cup of your place.
# It's wall what the condic left of the pack.
# (super)
# Good, I was the cossle and I want the sup of her out of here.
# You cant well what the nice not all the congic. You show about homes and hand and hand what that got out.
# It was got not got a copt and some cond, I got the medable.
# It's the congy.
# You do
# ----- diversity: 1.0
# ----- Generating with seed: ".
# All right, I'm sor"
# .
# All right, I'm sorry was a shoulliece... I just call ala manging.
# As.
# I hares what the guy out.
# "I meangows wholl good, I'm no wictle withorge! winder what speaking... They on this.
# It with a could forteety some agergion frie?
# You may God,?
# Yes, 'em it?
# Hell...., you dont want, you, how rodders? That, what?
# I sie I got thing, what are y about dool.
# Seening, what?
# I know, what ever hares wapery and a becaI, Ive mean
# ----- diversity: 1.2
# ----- Generating with seed: ".
# All right, I'm sor"
# .
# All right, I'm sorry? What's walkait? It's gor.
# A alway, you have at... I'm lift what?
# B-, I by how up that no...
# I'd really? You know, I'm, If!
# So, Givcture younek, on coN.
# istally utly of me., I got. I gave that?
# Your, KramcrcMinght, I bel's days, you don't!
# EhaHe.
# Go enated ato .
# .ving eur youghes.
# I just get loak, we protwa gett pant.
# How do I canlly viFish.
# ?o.
# Scity 'me starty klewa.
# )roter!
# voof, Ill twentic
#
# Epoch 00005: loss improved from 1.60939 to 1.58670, saving model to weights_jerry.hdf5
# Epoch 6/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.5516 - categorical_accuracy: 0.5369
#
# ----- Generating text after Epoch:  5
# ----- diversity: 0.2
# ----- Generating with seed: "nd yet still somehow"
# nd yet still somehow to starts a count was the man an against to the has to the back an a getting to the ham about to the storget a cound about the pook offent was the sind off to the picked of the course some to a count have to get a latting to the starting to the pack.
# I don't know what the best about the picked of the pack.
# I don't want to the pent off to the picked of the sind offent some body stort the parts to
# ----- diversity: 0.5
# ----- Generating with seed: "nd yet still somehow"
# nd yet still somehow. I can't see it way we're going to the brind, I couldn't are to knows the back on the chean about of my grabbed with the pook.
# I can I don't leatin' think you're it with her in the crought how is the mind.
# I don't want to strees of the hitt?
# What do you want to do you want to the come against count to the hands for the cook.
# All right of some body guys a little took off?
# So you're street to the h
# ----- diversity: 1.0
# ----- Generating with seed: "nd yet still somehow"
# nd yet still somehow could, So chake it) Oh the moursoques.
# Wh tYop a cher! Oh, you Orrack vermaco Kramer. Wh him? Thank do you been back out of this five. Kramer hick ag if thist's there is it Elat is the sie, sorges out it Od with thrys hour cabe, I geint on they sbours leaven to me a histcre.
# No About con'Tall about Lews.
# No.
# Ill even I bellin' in the haal us mount the babure, you're not succors dake a copen int,
# ----- diversity: 1.2
# ----- Generating with seed: "nd yet still somehow"
# nd yet still somehowar right. Woll you're sought it. That is like, I can that down Lews awellE.. Sot could even. What' You'ry stall back'd a lau" abrelelas.
# arrup.
# So, no am waant togr. answer abullly trame sImmurd. You know. I bame to you're yorring offorges.
# I could. Or the gabriesespictay.
# Okay...
# ?E?
# Oh Baug floor!. S- Exting some.Chiffyours tou tell?
# Tem (Geel a Clabuse.) ECaure-day. (Jants out ) Well, I'm guyt
#
# Epoch 00006: loss improved from 1.58670 to 1.57007, saving model to weights_jerry.hdf5
# Epoch 7/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.5402 - categorical_accuracy: 0.5373
#
# ----- Generating text after Epoch:  6
# ----- diversity: 0.2
# ----- Generating with seed: "ith her just because"
# ith her just because you do you can do you do you would you to do you want to be for the problem and to be for the prention of come on the prennard a little the back.
# Well you do you want to be a prention and to the press all and with that be for the proper of the proper presser with a mone how the proble mone money for the convies in a convie of my from for the prennar in the convion and problem the counded for that
# ----- diversity: 0.5
# ----- Generating with seed: "ith her just because"
# ith her just because a coving to was it won way a mone and of the pocetion and to like to prenned you to money friend for the coffee parts some a prennines back?
# Well you trying to prented?
# Alright, you got a little bie be for the piffellounce to the tanking mone a for the pacting too money. You want to believe my manaling mook off off of presself of the hingal make to prenna minally from that second, how you see the
# ----- diversity: 1.0
# ----- Generating with seed: "ith her just because"
# ith her just because exting, probably I got a litt see pook aboued in it?
# So ricten. I can't gong agaut about making anywas prectidy usel)
# What you can't trop some andert if yeahit!
# (Thes setiavion! I counday. I make mor the impuzed?
# Excuse a pae.
# But Stell yeah a back?
# He are youed see to people hocks to bugP actuse - arough no, the fort of what her is him, gongass gone out thouting down on this waitalve it woundree
# ----- diversity: 1.2
# ----- Generating with seed: "ith her just because"
# ith her just because you cook at you're waite days.
# Bhing, Bace? You got - you, thatsn't poestyed lotrinn to like Accen.
# Ill to.. , how is guys) ever need, we toess in differentAppresed like aga. put or Benciced... Why doey the falgs-Railing for Mrlics. I don't said I wannay. Hey doing to like to to you with -(What's thos) okay?
# Kra Kringing sind bring itas. Oh, You was dy toom. Mangy?
# have to shile.
# Why don't get gp
#
# Epoch 00007: loss improved from 1.57007 to 1.56184, saving model to weights_jerry.hdf5
# Epoch 8/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.5323 - categorical_accuracy: 0.5392
#
# ----- Generating text after Epoch:  7
# ----- diversity: 0.2
# ----- Generating with seed: "ny now?
# Oh, this is "
# ny now?
# Oh, this is a little parest the pass parts partan an against they was a beat the problem and I don't know what they looks a little poor and he's business and I have to be a bad an an a prectuate the pook and he are a little ponticing to be and I goes they was a beat there are your bad an an a clation and I have to be they was a beart beave in the back and I goess the pook at they was a beat the past the past
# ----- diversity: 0.5
# ----- Generating with seed: "ny now?
# Oh, this is "
# ny now?
# Oh, this is it what they don't know if you know I go to good and I have to be pi-ling in the picket.
# What is that would paid they bet one there have to be?
# (Sothing to it.
# What id that would pan they weat that past about proba someat here getting up and partt become things with her and know when they tooking the macheal about they don't was the bab?
# Yeah.
# You're back an again con'th.
# Yeah, that's there alled
# ----- diversity: 1.0
# ----- Generating with seed: "ny now?
# Oh, this is "
# ny now?
# Oh, this is blax.
# Sfuy already, I'm not's the renurtersely) Yes we hean beday
# do that kid out of Newman!
# What is good abeck tomething they just pnopeceed dewn who around I got it of a vattanothing to alk I'll break a But I lead fine it's like pick in it.
# Poss.
# You're your kipt it all that was a monie, puts prebin a dess, I'll it's faft it's you.
# I daid this Bace?
# WS it's an ompla?
# You pave Or aveng of here. (
# ----- diversity: 1.2
# ----- Generating with seed: "ny now?
# Oh, this is "
# ny now?
# Oh, this is you'll.
# Weel he gair to , pain bet qualst back up telweme, yeah!
# Y.
# I'm
# You got a? We'll Cang we treilvinge le'Us.
# ThaI was put it abale.
# That's Pugled poced?
# Whine.
# Yeah?
# Yeah?
# Os wy lla't'd pulll.
# (Georg dould) Is thing) In heardres mean Storr been a biguseay thun Fird) He's mymelly?
# (bup I he'll fort the people earat. (pats betters) LNsakow hougen the pioke. We woulerragear and Faock to five I
#
# Epoch 00008: loss improved from 1.56184 to 1.55360, saving model to weights_jerry.hdf5
# Epoch 9/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.5346 - categorical_accuracy: 0.5393
#
# ----- Generating text after Epoch:  8
# ----- diversity: 0.2
# ----- Generating with seed: " all right, this is "
#  all right, this is the care.
# What?
# What?
# Why do you can't do the pecond.
# What?
# What?
# What?
# What's the pick.
# What's the con plane.
# What are you can't we so not hand and he can about the clease.
# So what about the cleate the for.
# What?
# What's the door to the car for the people, I can't called and the counses.
# What do you can't do the pecond.
# What?
# What?
# So what do you can't were anybody one of come condint of the pick
# ----- diversity: 0.5
# ----- Generating with seed: " all right, this is "
#  all right, this is no streeting her the plane, I got the people of the place.
# Alright, I don't were the prooch for full.
# No.
# Well, I don't the knews that clead to something it. Its to a whole to make the counsed for the was for in.
# I'm for the daishes.
# Ah, I can't see he sore to make the pirting life to be colffee?
# What's with his a weep in the car. Did you leave you wald that pood for his pood cleane.
# What do you w
# ----- diversity: 1.0
# ----- Generating with seed: " all right, this is "
#  all right, this is sor's thing.
# Uhnustakre, I fices other boom, blake it. ploor, hourn's tonvellsmating..
# What are you do you can way evendsed a parfines) Why could you pect a.
# (Llay foor) So putty door Kramer?
# Whilder wa cares?
# Okay Soo?
# While misaking.
# I-never were kidster, I can't serey snceckint cop my face right, uhYeO. I love it.
# Yes. nuts.
# Kramer.
# What are you got to Newm, you're line.
# He pay to mover here?!
#
# ----- diversity: 1.2
# ----- Generating with seed: " all right, this is "
#  all right, this is for goy tre for sicua..
# JurTs fine volaull ges toh, right so, a little hwid?
# Well sto, Kramer do in tmokie excute), No.
# She exI veshollook.
# No.
# Ah, you're, surt?
# cllans?
# Okay. hell, I got. the dool.
# My cadI cally over norry do.
# No.
# She know, theyen. I'd you. Sfegnet, You'r'le lookin' at Casks.
# I atiges an iqpe!!
# Yes..
# A verly but?
# , that's fuln....... He's ven mansmer.
# Next.
# Welling to givid.
# (I c
#
# Epoch 00009: loss improved from 1.55360 to 1.55323, saving model to weights_jerry.hdf5
# Epoch 10/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.5386 - categorical_accuracy: 0.5391
#
# ----- Generating text after Epoch:  9
# ----- diversity: 0.2
# ----- Generating with seed: "t) Yeah, good mornin"
# t) Yeah, good morning this on the site of this what this what he know what you know what do you know what you know what is this in the show what is this histing his coming anything his for me and he come in the show you come in the many of this whole to me an on the chang.
# No, I don't know what you know what is him on the many is the charting me. (Shours what is this whole thing here. (thrill she come and what did yo
# ----- diversity: 0.5
# ----- Generating with seed: "t) Yeah, good mornin"
# t) Yeah, good morning a mollor me anywhat three mean and where what do you know what do you know what you know what a comereally whire you know what you know what happened in it of your whole chat me.
# I was want in my good of me me his doing thrown.
# (thing with white and mimman.
# (Stathing of the che sicks up, of this his back thriee slast ence this amone on the chock you appeends white how you know what is this might
# ----- diversity: 1.0
# ----- Generating with seed: "t) Yeah, good mornin"
# t) Yeah, good morning a check's famat out of this?
# No, I love this.
# What do her?
# No. Nothing me. What? (manging opan. Oh, whid's his And an long)
# Wellh, right. Eack uh he Seerita mast goat pomercom.
# Oh he kill puring here.
# But our amen. Immas like be a fight?
# Whis meing?
# Rema?
# Sant ye..
# Kramer consibel . dres ligass?
# And you lust, Elaines.
# No. You know, when all right!
# (thrilights anothing he get in a mind?
# I know ho
# ----- diversity: 1.2
# ----- Generating with seed: "t) Yeah, good mornin"
# t) Yeah, good morning hisresamset.
# (Daving his outly) be, I was bencuifll home.
# Do" (nowWell for th reston laster astuse who' have you doing. d" and who? mamch, how liven him.
# Hey with F musfeor grabs."
# (Coma"
# II youllar?
# Okay, symirge?
# No. Waut was you, you can't. (tice still of himmeid Elaine. ' fume. Okay. Hell Oh, well he gray goes throight.
# Oh, whin' whatchere you, but you werent owf eem me piate me?
# Let you mre
#
# Epoch 00010: loss improved from 1.55323 to 1.55192, saving model to weights_jerry.hdf5
# Epoch 11/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.5321 - categorical_accuracy: 0.5424
#
# ----- Generating text after Epoch:  10
# ----- diversity: 0.2
# ----- Generating with seed: "ge.
# Okay, okay. I'll"
# ge.
# Okay, okay. I'll got the would be the out of the words would be the come on the workic.
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What?
# What
# ----- diversity: 0.5
# ----- Generating with seed: "ge.
# Okay, okay. I'll"
# ge.
# Okay, okay. I'll get the wordis the working and all this and feelice.
# What?
# What?
# Oh, he's the worst.
# What?
# What?
# What?
# What?
# Well, I mean that well they reought like and a frille in the show he stay.
# What is a money?
# What?
# What?
# What?
# What?
# What?
# Way I was out we read in the being. I think I know what are have to get the way to here.
# I thought the something.
# What?
# What?
# What?
# What?
# What hum?
# I don't want the way
# ----- diversity: 1.0
# ----- Generating with seed: "ge.
# Okay, okay. I'll"
# ge.
# Okay, okay. I'll gueling too!
# But I was goving. Now what?
# Ill to
# Yourllest we dont out wom well, where what?
# (wanky get in
# (Bic
# I think theyround you.
# No, thah I is thoubl.
# I it.
# I wild sheshday. Ha Jell.
# What?
# I shake I was I wouldny a some then tro?
# Wmuch, held my just?
# What's aa?
# Is they likes.
# Who is that?
# Well, Took acviou, that in walk of wompactioul to you! in houd!
# What?
# No, 'a cu picks. It makes everyst,
# ----- diversity: 1.2
# ----- Generating with seed: "ge.
# Okay, okay. I'll"
# ge.
# Okay, okay. I'll w, leting is... now, I don't knewith, I' had, Nak a Ill st)reet Y (wanks
# Woncal veive so, that at. He -estity. Justey look I knew to so, the smabres and they retruile be orght, th. ...
# It!
# Oh, vey weys on's heacky.
# For kecky like I... (George.
# Well.
# Well, nores, I don't, I mean stause.
# Srow neves,tory! I right, over.
# Kaageyd! You stiet.. You'r very neshtion would be -  and been my mote
#  what I we
#
# Epoch 00011: loss improved from 1.55192 to 1.54697, saving model to weights_jerry.hdf5
# Epoch 12/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.5177 - categorical_accuracy: 0.5455
#
# ----- Generating text after Epoch:  11
# ----- diversity: 0.2
# ----- Generating with seed: "gonna be coming over"
# gonna be coming over the controom.
# Hey, I don't know the worgance.
# Hey. He weat in the confieless and but I don't know the worthion mest of the people of the pick to but I can't the picked to by fight one of the pickless and and and and good in the house and and on the conce on the pick of the first to big ficess the pick in the connice.
# Hey, I don't know what see his the pack in the conce on the concolan in and and
# ----- diversity: 0.5
# ----- Generating with seed: "gonna be coming over"
# gonna be coming over with the with to Mornever hear and I don't know the worthions would your arend anyone another sard of a carres. We went thing on conce on and an if you can't never goen there. He doesn't even I don't leave the funny, it's too bage. It don't know the envat game on the connent of here. (Laurss heans still picks up and his but he said out was another bark to start leaving me.
# What are you doing?
# Wha
# ----- diversity: 1.0
# ----- Generating with seed: "gonna be coming over"
# gonna be coming overfican from of crackess -est okay in the planing oh. The bucks anging to likes?
# Well? You mean, the salst one then to hiarst you going to by sits been and, we pucks to! What's otbend to riptering thingory, I know the ('an orveation ghing to my hugncecats?
# I Uhes no LTeverracoticar pill so breakloopa)
# I don't evened a di, we enterss to wanna cank in mystreical feld? He hans to The gny toes ochenna,
# ----- diversity: 1.2
# ----- Generating with seed: "gonna be coming over"
# gonna be coming overt.Frigrat can?ng's gxce.
# Whe Reen yourd Slamcate!
# Well, were I have furly then? (th-
# There) oken on ederonive me. I in this cranday.) firfile?" Theats to Lissuides?
# Excusanoving Je!hey's Your fife)
# Hey sees, meat wear hwar questeal. He ldations on atenomeno. You dorice?
# I Elaine, Georges a amagalle, piest dolling maybe hell rumestion, look at.
# Why'd mefto see white?
# Hes anymerly if why called I (d
#
# Epoch 00012: loss improved from 1.54697 to 1.54575, saving model to weights_jerry.hdf5
# Epoch 13/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.5356 - categorical_accuracy: 0.5411
#
# ----- Generating text after Epoch:  12
# ----- diversity: 0.2
# ----- Generating with seed: "think you're going?
# "
# think you're going?
# Well, I have to hear a couple of here. That's on a guy not of his of me a couned of his of he doing to me to you good in the houp. He was a come on here off it on here. This is a guy in a couple of here of it out of here. He was her here on the counce of me a couple of here on the houre of he doing to me to you going to be though how you good in the houre of here. That's not going to his me in the
# ----- diversity: 0.5
# ----- Generating with seed: "think you're going?
# "
# think you're going?
# un that in the rise. He going to Kramer played me. That's for on the hang of he doing in to me the counce in a coopletely on his mack of you be hour around out of the colatent off. He had to me a little or a because of hein really salday do you head so what you know, I had a complamet book and pourt of your post to there, how maybe what it was in the only something a plane of he guys in the pick e
# ----- diversity: 1.0
# ----- Generating with seed: "think you're going?
# "
# think you're going?
# Can't you do
# I get a wat ok. He oug of ahherusan, it, way heally. They're sorring maker hook a for that smalleGg?
# Can't being. What sayunt out to Jouse having my eal off out off footles deI !not wish party?
# Hey m! your foo! let to ent, I mean, on there plancher leak a little in those houre good for time overed to did I know stilled airrounched Ts.
# Well loen.
# So you hape a pargan. - oather on has?
# ----- diversity: 1.2
# ----- Generating with seed: "think you're going?
# "
# think you're going?
#  achorf coursed of me you - pperY wercing my ever morm in my elbo-on bristuble opa. H at's going a forly. zoudin't bingled open) What happened that, guys handing forn anyon didnnytiousen't you calc heip. You challed a mine-Hony good you couldre, alliary? Its hopped wing goes whelem, noine bain atolon. (Shoogano'vouse whole ill Yor hook in expiak eleving Awoured, I has happony oullen with  on you.
#
#
# Epoch 00013: loss did not improve from 1.54575
# Epoch 14/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.4321 - categorical_accuracy: 0.5701
#
# ----- Generating text after Epoch:  13
# ----- diversity: 0.2
# ----- Generating with seed: "Kramer)
# Oh, it's Geo"
# Kramer)
# Oh, it's George in the conviestic fight. I don't know what are you got to get that with the convers to you see that we have to get the pick up to the has the pick up to the conviouses the street and he got to his bad be a little weeks the man any the counts and he was going to get the conviestion the rest yess a guy in the picket.
# I don't know what do I want to get the statter. I don't know what are you got t
# ----- diversity: 0.5
# ----- Generating with seed: "Kramer)
# Oh, it's Geo"
# Kramer)
# Oh, it's George, well you do the beatf me a mysters me.
# You don't want the halls.
# Boy, I maut here a colde the stop and what stoes istersed to the mad. The fist my many face and I got to you something?
# I don't even have to see it about the with him for here, I can't see you for the care?
# Oh a guys steakan that that back at the condical leave the phone! And she does the man for here. They mean be work the bein
# ----- diversity: 1.0
# ----- Generating with seed: "Kramer)
# Oh, it's Geo"
# Kramer)
# Oh, it's George. Okay, of all anmoslowing him is against to my kind of course.
# Your meding it over would linet helliness he doesn treis the Vaselly with to hellod.
# Hey, if you sore?
# What maybe you know, we'll know?
# Yeah. He was working aty that bal only with me action that and pkansiathlat. Tell me. I don't know, doesn't leave the siticles of firf toortic leughing to fland!
# (What) Ecat chunce, dost care the h
# ----- diversity: 1.2
# ----- Generating with seed: "Kramer)
# Oh, it's Geo"
# Kramer)
# Oh, it's George imaginion, just! This UP! viot pocket, "wes, a, women spitie.
# What aspure?GOOder encave need. Pefper!
# Elaine, (Kasmelipt youve to be heic.
# No.
# !the paper Kramer. uh togwed gitle back going, Ah, you don't intracting the Chisace. use wheng de a lod...
# (leagin) BazKming from ligt! Dont wear that wouldn't happy?
# Okay? I moving, thabyes.
# What?
# (looks" mialen to wisp your faul.
# BecDeat hmayactines h
#
# Epoch 00014: loss improved from 1.54575 to 1.41285, saving model to weights_jerry.hdf5
# Epoch 15/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.3452 - categorical_accuracy: 0.5928
#
# ----- Generating text after Epoch:  14
# ----- diversity: 0.2
# ----- Generating with seed: "h, it was a real tre"
# h, it was a real treating mind.
# I don't know what the mallad it in the pick up to the back of the street back of the street and he doesn't think I can been a sitten to get the man and he doesn't was the story. I don't know what the work at a couple of the pick up to you good to go out of the side of the side of the man the story?
# You don't know it was the man a good in the contie.
# Yeah, I don't know what the has the
# ----- diversity: 0.5
# ----- Generating with seed: "h, it was a real tre"
# h, it was a real treating place and it was gonna have a couple of me. I mean, he was it out of the sing, I had to have a whole life?
# You can't see it was like to go little like to bad you got to be your one of the street bad a cook.
# I love that anyway. The whole table the house in a saloodd. You can tell the out in the beith poess.
# So, you know what what to be your ving you stand it want to go to the bad with the bea
# ----- diversity: 1.0
# ----- Generating with seed: "h, it was a real tre"
# h, it was a real treal.
# Alright undersave?
# Huh? What Nobber, who ever days on letsuning!
# OU, I mean, I mean boying wheasionshed byed terlinaytion--off a problems?! You were the car! You know, organual to this from right hand comns wanting's me about on and.
# Who I stuff a good on the susbellway. He.
# you duyse fight bewas nuce now enigety with '
# Hen ruct. Hello.
# What are you going himm.
# Yeah. (Kramer in the creemelst g
# ----- diversity: 1.2
# ----- Generating with seed: "h, it was a real tre"
# h, it was a real tren.
# No tourd, them If Newmavia's!
# (to ofey eed asked.
# The myan.
# Oh colls..
# Alrightras, and dobidnish spere other tablis down know fome?
# 'sabstee of miul, like me.
# Hudgook, we shere just gonna calla. I and there go?
# You put in the race..
# Yor reaspes, plaper misle?tO stfo.
# Ahk. stames what tabbe gaiming memat.
# What's briggl ever gerl top of Ony pot rylemine. Well, watel have had nect op in their sanc
#
# Epoch 00015: loss improved from 1.41285 to 1.34721, saving model to weights_jerry.hdf5
# Epoch 16/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.3038 - categorical_accuracy: 0.6036
#
# ----- Generating text after Epoch:  15
# ----- diversity: 0.2
# ----- Generating with seed: "ner; thats heavy. Th"
# ner; thats heavy. That's the siderience.
# That's the sitten.
# I don't know what the streeting the story on the sight, I don't know what the streeting anyone the tood.
# I don't know it and have the bad because of the street on the bad story on the sing the story on the side on the straughther and she was going to be the street bad a couple of this concome on his about it.
# I don't know what the way anything to be an and s
# ----- diversity: 0.5
# ----- Generating with seed: "ner; thats heavy. Th"
# ner; thats heavy. They don't know, I got the steck on the last my thing the car an ortend bat here, you know, I can't go to the sumbor care.
# What do you know what?
# All right, you should stay an orgent fina kind of call the check and I don't want to get that back to be the second. I people one the head. I don't know it was her thing in the has pocket of the poop in a little phone that starts to his good. It was gonna
# ----- diversity: 1.0
# ----- Generating with seed: "ner; thats heavy. Th"
# ner; thats heavy. That's diffie, I Haven't get that with my that meh, uh, just trys Lozing
# you say Stattogly go and Hove capera sit idea wi-here to like it in the bumber's a wholding to for my Haip. We not guy? You can't I ask now you didn't remish.
# I vermin a gyver my machine two'd you got that symate gorgaton?
# The alreccuted in, I got like this Maraper but I have to take five meet houre to soundy, Good, staying, y
# ----- diversity: 1.2
# ----- Generating with seed: "ner; thats heavy. Th"
# ner; thats heavy. Then the glis, should care.
# Hing habsed sap you an'
# It wake
# in thimms?
# Aw, wh.
# So theys a tewnie. (MNxcubaly becaus) The daMrry. You know how do .?.Wear?
# Hey, you know, what do? !Wnat, Elcenight. We're very going. You know what you didn'tor take a was that?
# Into sups tell hoin. You can I dont pastans insurbed havhy is out and megount eary flovin ad over.
# When she's askin' af let elcoght.
# Talking, yo
#
# Epoch 00016: loss improved from 1.34721 to 1.31206, saving model to weights_jerry.hdf5
# Epoch 17/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.2791 - categorical_accuracy: 0.6124
#
# ----- Generating text after Epoch:  16
# ----- diversity: 0.2
# ----- Generating with seed: " it.
# She will tell h"
#  it.
# She will tell her to the street of the streeting me to the sinks in the story fall and he doesn't think I can do that thing is the movin is a car use the story for the street of the sinks.
# Well, you dont see it to the story for the street of the sinks.
# I don't know what the streeting me. It was the matter of this his store the street of the sinks, the sing is some toor good the place right her too much and I don
# ----- diversity: 0.5
# ----- Generating with seed: " it.
# She will tell h"
#  it.
# She will tell her to say of the stromone whole to me to a whole life and he lives weers?
# Oh, you can do that finary a stopory for the trops. He figant the pecoon the car and the bag dollars a complice the siffing the bain the back and I had the hand it a hall for a complater.
# The strees. I don't know if you think I sweep the check about the statted a back of this check. I can't believe this pocket to his siderin
# ----- diversity: 1.0
# ----- Generating with seed: " it.
# She will tell h"
#  it.
# She will tell him her live, 'le sull now up in thes. She came he should be ahe?
# Yakne, you, how's relating.
# Oh.
# It's T'dable, you?
# How did you mean, fight. (not kindin sa) Swersy Joun! Hello.
# (tocaus) ) ) She care he lauels that imagirill hair word for his bowland I'm away.
# a talk in the door ammening your hope of forta fiffeine)
# What do you get your mave. . How did you can know if you got now.
# What should you a
# ----- diversity: 1.2
# ----- Generating with seed: " it.
# She will tell h"
#  it.
# She will tell houp, were buzzer!
# I'd alwrith the reto. Why? Thanking Newmole whes gonna shmverys pretty fine. He was that hack what you sfor her some dony?
# Ben this?
# Nah, you dont Ras breag, you got to him. veverxence) SkeysT sleed on hissipting huhch?
# What?
# Theys (sares about beini, wrat thinkicedl. I fell both heal.
# Will you ryven?
# What? What's of this? Ny.
# Ajour hised your tabliaping amagay back And rulks. w
#
# Epoch 00017: loss improved from 1.31206 to 1.28465, saving model to weights_jerry.hdf5
# Epoch 18/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.2448 - categorical_accuracy: 0.6226
#
# ----- Generating text after Epoch:  17
# ----- diversity: 0.2
# ----- Generating with seed: "I met on the plane.
# "
# I met on the plane.
# What are you doing?
# What do you think there was a street of the store the street of the street to get the only the stop the ball me and of the street and and I got the stop it out of the show the ball the street of the stop in the story.
# What are you going to be a being and he doesn't think I can tell you and I was a with the bad better of this concellon me and I got the way and he started the sto
# ----- diversity: 0.5
# ----- Generating with seed: "I met on the plane.
# "
# I met on the plane.
# I know what the paper a chopsed.
# I don't know what they really to get the isn't the for the sitting about the pictuse of this hand for you.
# Yeah, what do you have to me?
# And she gets this but I could be of a big moves the only again in or a little pat here.
# And go to the show like that place in a little to the street out of the streeting me and the stopent the only come on the whole closed in a ta
# ----- diversity: 1.0
# ----- Generating with seed: "I met on the plane.
# "
# I met on the plane.
# Ok my the conneed?
# So Caver where det it same out the coning?
# What about her?
#  whole midering in it, All really past pretes.
# Yes, I'm swearing a machine, it's noo up whros in your sawance Builhed) Krumer out on the chea.
# cupRry place.
# Well, OnotKE!la?
# Okay, thank you, I had a seen?
# Here Ran, I'm sure not I got there girls what the ewide of course. giver his notigents, what shell-up not of the on l
# ----- diversity: 1.2
# ----- Generating with seed: "I met on the plane.
# "
# I met on the plane.
# I dont cant like the same a cuffun to is mirl place. IKca my now psonsuing there you.! That's lefts somebody, in really nice. (Joe enefreten Benoth! Sonj!
# The dofeon,, uh but the whole pil good m.
# Just.
# I'me one room, it's gonant magin name, I get you?
# Hif over grive getter in for Eltines fifty his bumb
# Youre I steeligHn' I'm ople prots. up, someone, pwold the bena?!
# Oh always anyway?
# Rame! hg?! K
#
# Epoch 00018: loss improved from 1.28465 to 1.26335, saving model to weights_jerry.hdf5
# Epoch 19/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.2322 - categorical_accuracy: 0.6268
#
# ----- Generating text after Epoch:  18
# ----- diversity: 0.2
# ----- Generating with seed: "f you could ask a wo"
# f you could ask a woman to his back and she can the staties and all one of the street back on the street of the semong here in the hand the street bot of the sinks.
# What do you say an or a good and and he doesn't think I can do to get the bancer.
# What are you doing?
# What are you going to be a little seen a complietching and he doesn't think I can do that think you can do that see you the street your concernge and he
# ----- diversity: 0.5
# ----- Generating with seed: "f you could ask a wo"
# f you could ask a woman and he goes to go. But I remember to see you going to be work.
# What are you doing?
# Yeah, you can do to be whole from the stink his hand in right, you can go to see a little the stopened in a matter. We looks in the pony from a little player the pant to really like the working and have to talk to see that stuppos the me side and she cares and ask you wanna say anything to her hours not here lik
# ----- diversity: 1.0
# ----- Generating with seed: "f you could ask a wo"
# f you could ask a woman a down the pevie. (And my really placen. And he say I were was with it hanging can heart. Dowen he says crise.
# D(e guest call) Thet's right. They chanted to be comfortable now, and I'd really think thats no Elaine beed your collar maller?
# Wolline shit, then off.
# You're motely been in jank. He Netmon indog. And I seem she caranened?
# You ling be wolling and be something parking forsed this guy a
# ----- diversity: 1.2
# ----- Generating with seed: "f you could ask a wo"
# f you could ask a word we traying bessing just said this on. Not guy mist, have the next witht bovS" of? Were around, Peshi, I make its whole about it weading.
# Of are effecred it.. They heard.
# Lice is.
# Oh I can't tuse a cabreill.
# Yeah, if you ."
#
# No, Not, I, ijs uwnt cack Pat the same itd. called me, ble batching?
# No. bye buts a co yes it?
# We'de timen? Misom, you came a grind? pit the book spot of fun in Atoon on now
#
# Epoch 00019: loss improved from 1.26335 to 1.24453, saving model to weights_jerry.hdf5
# Epoch 20/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.2157 - categorical_accuracy: 0.6325
#
# ----- Generating text after Epoch:  19
# ----- diversity: 0.2
# ----- Generating with seed: "purse. I carry a pur"
# purse. I carry a pur a man and we gonna have to get the sink of the side of the people the counts.
# What are you doing?
# You know what the man and she can stather want to get the paper the only the paper there are to get the story me to be the sittion the stop the sittion. I don't want to get the people the work. They don't know what the hand in the bad because of the side.
# Yeah, I don't know. I don't know what the sto
# ----- diversity: 0.5
# ----- Generating with seed: "purse. I carry a pur"
# purse. I carry a purlans and have the people like me a videra sure is the table.
# So what do you say anything?
# What do you have a little too many. (prats to bing of the conchught and they think I'm going to be in the conney. The late on the car. And I can't believe anything the has but I was her to good this high... I don't have a new can the fact to be good. What is that? Ive have to see a live the house around the p
# ----- diversity: 1.0
# ----- Generating with seed: "purse. I carry a pur"
# purse. I carry a purnent work, never had a night, Bevis namine. Ah, just see you a pidens.
# Oh my fightrabove, else askey if you dont know why me to.
# If it's not Rannamin' about it.
# washe's not gonna det in the game... I don't keep the matter) Oh my heast ma juster was I three mesible to soon, I'd know, Uh.
# Losich day pickin' if then on the counce-bur) Lts on the appered me. Boy, you knows come in.
# I don't think I'm t
# ----- diversity: 1.2
# ----- Generating with seed: "purse. I carry a pur"
# purse. I carry a purra!
# Alright, strention, what?
# (thinks loke) Of astom. Beched you, letch, this for this puglent byes.
# (OteJeting oex) Oh, naver, a capry as machine big tlam, in Said charra.
# What's the wouldnne?
# Yeah, uh. I have George on the nughtces, plane.
# Hello.
# You know, Ill muted low over apartment was outs, leave's suct off a duck.
# (anto to the place) What's there??
# 'CaW? Hell ElaP. usno I have telis her. Ca
#
# Epoch 00020: loss improved from 1.24453 to 1.22924, saving model to weights_jerry.hdf5
# Epoch 21/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.2004 - categorical_accuracy: 0.6354
#
# ----- Generating text after Epoch:  20
# ----- diversity: 0.2
# ----- Generating with seed: "hat do you do?
# Alway"
# hat do you do?
# Alway, I was a little phone with her of the connerd to me the conversatters of the something in the conney?
# I don't know what I can tell the movie the with the streeting here.
# What are you doing?
# Oh, you know, I don't know what the hall the movie the plane.
# I don't know what the has the pick up to go and they was a word of the pick up to the street of the streeting my fame, they was a little player the
# ----- diversity: 0.5
# ----- Generating with seed: "hat do you do?
# Alway"
# hat do you do?
# Alway...
# Yeah. (noss the book to go out of the counts the first too.
# She doesn't know what I can do so a lot to get a high...
# What's who?
# I don't know I can't do that go out in the door or his chook of the car and we gonna have the time of the story, I cant take that with a little treped in and you got the coffee on the cook and I trying a problem ground there's no regonne of the big frue. (a statter o
# ----- diversity: 1.0
# ----- Generating with seed: "hat do you do?
# Alway"
# hat do you do?
# Alway, be serculan gets.
# I'm going to butly wish makes for heralimglos.
# I don't pay?
# But I wouldn't say another wanna toor for over to and with the xanle.
# ead, a clots all them an in.
# Hey, my being the one cort with this in the guess from going to get the down hust. What are you have it out friend subway, Don't think not only the room, they epes, I know what ome's buttering. (To outhing up to.) there's
# ----- diversity: 1.2
# ----- Generating with seed: "hat do you do?
# Alway"
# hat do you do?
# Alway, sometay, I remember. You know, it! (Newmer bough, ahy con't, and known kinda go thin. yaum, Io but comes)
# Rimat.
# We'll go a hair Gao..
# Ye's stup.
# Hello? ...
# Wea's a pancas fayip we could go "Word. There's a situad?
# So you like MarubW. (Events here Hanuit him. But Think you'd get no.
# Firt, just turk one terrso? WhatRed endy fise.
# Remember it...
# I'm surid I'm coleing an ippub.) (So whating like re
#
# Epoch 00021: loss improved from 1.22924 to 1.21532, saving model to weights_jerry.hdf5
# Epoch 22/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.1861 - categorical_accuracy: 0.6407
#
# ----- Generating text after Epoch:  21
# ----- diversity: 0.2
# ----- Generating with seed: "s; Cain had no nuts,"
# s; Cain had no nuts, and I have to get the semonly and they had a compline.
# The way anything to the street of the semong.
# I don't know it was the stop to her on the conviesticulationship in the connerts of the story of the street of the street one of the seming to her on the street of the story for the bathroom and she can I get a complate and he said I can get this my face and I get the with the bathroom and I got t
# ----- diversity: 0.5
# ----- Generating with seed: "s; Cain had no nuts,"
# s; Cain had no nuts, and I dont want to be my mind.
# Well, I got to trease of the concounner what I said to you go a reline.
# (points) The man and something about the ball here.
# What she see mecing my building me to the whole trying to tell you and and he doesn't get a colat and they got the steen of a little should know him of casing the sinking and they knows the conviestiond the remember of the strauselance. It's th
# ----- diversity: 1.0
# ----- Generating with seed: "s; Cain had no nuts,"
# s; Cain had no nuts, he did that it.
# close and you load, she Ilen't go back the pick' up, Cashan?
# Yeah.
# No, nothing it. I guys seving chest, only not Boyle aparuitsed. TPETHAry why necre. (time was gone. Lets go do it with it, laK, and she had in, it's ay menting. nothing activatuse immorone in the cloon.TWis so we know, what could he have your dreades would phopenardiring.
# ...
# into the movie.
# That's sJerry Guideraftry, we wonderys, the Sider, muct. Turcrouing the waterparath tryy.
# I mean?
# Hinglen Bog.sty.
# Now she -
# (Iinpeff We of im af elatade, and Imone med bent like it would do that?
# Wait another?
# Ohnoy!!
# Keanday?
# fock, a maplen. Oh, that's your boil pody. Youve befors tool, I dont think doesn't. Who way Wommin' long Too.
# ( To Elaine) he's Wire now..
# Oh, 'hey great.
# ', my from.
# I didn't
#
# Epoch 00033: loss improved from 1.12948 to 1.12390, saving model to weights_jerry.hdf5
# Epoch 34/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.1035 - categorical_accuracy: 0.6653
#
# ----- Generating text after Epoch:  33
# ----- diversity: 0.2
# ----- Generating with seed: "onna surprise Amy. A"
# onna surprise Amy. And you dont think I can do the sere of the best when the bat me a little parts of the store that what the stop your car and I had a good at a compliter.
# Yeah, I don't know what the store that startaniah on the street of the semong of the sink of the sink of thing.
# Hey, hey, what do you have to get the book and he doesn't think I can do the me to the sinking a mother back and ask it and I don't kno
# ----- diversity: 0.5
# ----- Generating with seed: "onna surprise Amy. A"
# onna surprise Amy. And you have to see it?
# (Instatter outs the stock yess my fling me. They really think I can do the simon a down to get in the side?
# So what are you doing here.
# What happened?
# You don't leave you with him and he doesn't think I think I'm enother being to get too.
# I can't meat some those that I had in the bewing your cat the ball money.
# So what do you want to get the ome and he said you can standing
# ----- diversity: 1.0
# ----- Generating with seed: "onna surprise Amy. A"
# onna surprise Amy. And wkat this, "Ilen middy the sifful. He was or tipet how he have a garting for now.
# Well, we not want to do this. (ment runnint from comerronst hor garst night.
# You know, I don't know a complate.
# Hello?
# You anderstand we say I have taking that came cresighty, you know, George I insuater)
# Yeah.
# What do you meen we got out up and him.
# is?
# I dont would see a little phores offine.
# I don't even want t
# ----- diversity: 1.2
# ----- Generating with seed: "onna surprise Amy. A"
# onna surprise Amy. A Ard you pic.
# ...
# Kramer? as Tast. I'll try to really toak vessutrobalbly forman? But I mean, is uhing avony?
# flut?
# (looking) No, ucco tellone-wall... pauses for?
# was'n't go.
# No, ere Newman.
# Who knows she is Hand I trep I'm Seiling.
# un here.
# Its might but I picking Cumiss. We show doing? Hman?
# Yeah.
# Yeah, 'ice. We ldat thousand doble.
# You do now are wearing your ficesser, the matage?
# (puts the ste
#
# Epoch 00034: loss improved from 1.12390 to 1.11907, saving model to weights_jerry.hdf5
# Epoch 35/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.1051 - categorical_accuracy: 0.6618
#
# ----- Generating text after Epoch:  34
# ----- diversity: 0.2
# ----- Generating with seed: "t into these terribl"
# t into these terrible.
# Yeah, well, I don't know what that was the big doctors to you doing that work? You know what the stop some realing in the book out of the street on here.
# I don't know what that we see that that was the coffee shate in the book out of the peoth.
# Yeah.
# Yeah, you're going to be with the door of this box.
# It's the book of it.
# Yeah. Yeah.
# Yeah, you know what the stop some sitzed of the beiclly) He's
# ----- diversity: 0.5
# ----- Generating with seed: "t into these terribl"
# t into these terrible.
# (to the lation and they got that we got to a couple or her and hand'd you take it enter conviestions.
# Oh, no I don't want to go to the back.
# Oh yeah. as Elaine.
# Yeah, you should just have me. He was conting to the way.
# I don't know. I don't know what the tan a care.
# Yeah, we have to the cook of me.
# What are you doing?
# Hello.
# Hey, be, they find that statter good. It's so remember go, be at here
# ----- diversity: 1.0
# ----- Generating with seed: "t into these terribl"
# t into these terrible.)A covone you supples?
# Im going to deting more.
# Ye.. Yeah, why crays I think Joen do?
# Hello? Hard- on, thats course. Make Newming on) dow?
# To yo. TeWmo thun. Even hahhuse dound to be paster.
# It's a weary something to whate didn't feeling. I can't do specom?
# Yeah, I dont have me.d the meenciars the (witherday bestoring the of those secial convietw to bulleppory. BetUeve thing agan simiou, like I'
# ----- diversity: 1.2
# ----- Generating with seed: "t into these terribl"
# t into these terrible bug you do. You know that. I didn't have on out olothver because. She we devershing?
# That's me.  prose if you had at''s her?
# Da-unt with Geod?!
# (Points purtion partion oftant completely...
# er! !haping thirt flirks the witen' girl on the with in Kramer's weary glad over Tim.
# Ya! is tell you you.
# I'm makes too, that's simion. (thinks listreed I know. I'ckn's doing. how scrack yel, or Cara(le? jist
#
# Epoch 00035: loss improved from 1.11907 to 1.11399, saving model to weights_jerry.hdf5
# Epoch 36/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.1004 - categorical_accuracy: 0.6656
#
# ----- Generating text after Epoch:  35
# ----- diversity: 0.2
# ----- Generating with seed: "s going in.
# I don't "
# s going in.
# I don't know what the woman to me the bad be there?
# You know what the stop some sitzed in the pick up at the pickle.
# I don't know what the buhhhy show is a little doin't the ment the pick up enter and he doesn't think I can do the ser a pick up and he doesn't think I cant be the door intell you and he doesn't think I can do the selingire the work. I don't know what the woman and he doesn't think I can bee
# ----- diversity: 0.5
# ----- Generating with seed: "s going in.
# I don't "
# s going in.
# I don't let there and see it.
# Yeah, there's not when the bett can the pick up.
# All right. (looks a latacting at me.
# What do you have an enter in the best ponsion of this.
# I'll say an end a lot my night. I should have telling for the store to go out on the way and all don't see him a whole placer on the words the food, it's a lot the sitter of the conservation...
# Well, and you have to get the phone's a big
# ----- diversity: 1.0
# ----- Generating with seed: "s going in.
# I don't "
# s going in.
# I don't make you?
# Who id it gonni against.
# tee shoulding.
# Oh Maron!
# (bad) I'm other swedist here. Oh, Elaine do. (ind.
# I know what we're wanting uncouldent night.
# (Pats)
# I think you sound very ridered. From three hal see married other good, way's genton'd that spot on the selway.
# The deciped ripped doctor?
# Why? ma tell your self to diven. I can't evening Jerry esgirys. I can't know whats let been I live.
#
# ----- diversity: 1.2
# ----- Generating with seed: "s going in.
# I don't "
# s going in.
# I don't think she's a pick up.
# Its woman trouble.
# He makes it?
# Kramer.
# I've sliekfuned.
# That pout someone gonna polder in here back of like a hignd aparess. Wouldn't we gonna hall to  another disfuliouse.
# Awain' I'm fululleblet?
# You know these people, andor outsual, Ns. (onitile) Ohy! you have to be of this mystrafty?
# (to al's) No, well, I'm AndryWh-t'under an reline ment.
# It's already? It's like tough to
#
# Epoch 00036: loss improved from 1.11399 to 1.11076, saving model to weights_jerry.hdf5
# Epoch 37/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.0904 - categorical_accuracy: 0.6676
#
# ----- Generating text after Epoch:  36
# ----- diversity: 0.2
# ----- Generating with seed: "t.
# Thats comforting."
# t.
# Thats comforting. It's a lot the pick up and she doing to her out of the book and she doing to the balls and I didn't think that work to the story. The door is a sings?
# What do you a work? They was a little panet.
# I don't know what the store that with the balls and he didn't think I can do that thing?
# What do you think that worked the money because I don't know what the store the concomen strouthing the stop somet
# ----- diversity: 0.5
# ----- Generating with seed: "t.
# Thats comforting."
# t.
# Thats comforting. I'm not in the first falls, the story from with the counts.
# I think I mean back the guys get in.
# I don't know. I dont know what I really tries to see the approping her me, the woman carrasion.
# What do you think they really think I want to me to always and she sad the ball?
# What is that?
# What happened?
# You don't know what the store the money. (Newman) Hey, hey, youre keep the arta laint.
# Ah, I don
# ----- diversity: 1.0
# ----- Generating with seed: "t.
# Thats comforting."
# t.
# Thats comforting.
# No.
# very, To hey, he keeprethered. There's no selabout that that women ride and we know you. That's no nose Or you arentage off Wishaby that he and she muster into money stack exuse?
# So I didnt moving here.
# You have the dointer?
# (while in fight thing, I got it.
# Hey.
# So you big doing backed of scenlosh. (Hang anothey) Wha-ghbore, it without her enuelw 'smatter order.
# The counts a vie! anow, comes
# ----- diversity: 1.2
# ----- Generating with seed: "t.
# Thats comforting."
# t.
# Thats comforting. spench. ... Butter ures, Im shrake a just not - dogs, um at roon me.., there's trenutes.
# (Nnisias, way's stayhbor. Now you were fooding your wade there was your really at around, and Iusald stoeally because he ?stait me, if was forwall.
# Who woaller time, I got in my hold, Sumable nuttes..
# It's coffeeno! (placing about the balarr...
# Im ro-fectK just this. This is amsugnd hell I don't think you can
#
# Epoch 00037: loss improved from 1.11076 to 1.10648, saving model to weights_jerry.hdf5
# Epoch 38/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.0936 - categorical_accuracy: 0.6655
#
# ----- Generating text after Epoch:  37
# ----- diversity: 0.2
# ----- Generating with seed: "in a convent.
# What i"
# in a convent.
# What is that?
# What are you doing here?
# What are you doing here?
# What are you doing here?
# What are you doing here?
# What are you doing here?
# What are you doing?
# Yeah. Yeah, you know what the store that with the concomen there and she care on the street of the second. (looks on the stact of the street of the seme got that starts to the semoni--
# I don't know what the sume the bathroom.
# I don't know what tha
# ----- diversity: 0.5
# ----- Generating with seed: "in a convent.
# What i"
# in a convent.
# What is that?
# What about the condicion, I can't go doing in his right hopped all I want was the signe the codding around in the button to the sink.
# I don't know what?
# I don't know. (girst to the streations here? I think I never starta back of carry.
# What is this?
# You didn't think they found a planet watch down the fight now it up with your factuat) no bupped. Bye met stupidned up with a virdess, what's
# ----- diversity: 1.0
# ----- Generating with seed: "in a convent.
# What i"
# in a convent.
# What is down? Ialle. I can do with over it.
# Yeah hears anymoreed and by oaloup crasht the show car I have a once you go an e-ry much, your keep's just ciff. A comp ind?
# No.
# So you're going to poors
# wait a loind of with anyonented with someone my didn't eat.
# I'm drinnate, it's the shitcasbodood at add-upor?
# (to Turn too) On, last where , though tomorrow... vies thats shock with buck. He we ready hous? Sh
# ----- diversity: 1.2
# ----- Generating with seed: "in a convent.
# What i"
# in a convent.
# What is a relata?
# Oh Strenutanis guy, "Then (weykn a chang)
# Coutch some, its Sandwere ulligged! like with on-on with you, know infores to seem) Dies? I think I is on the receter up of Mess his sunging your on a shocks poor poopledly wep.
# Really?
# From?
# Nah.
# Loak that get idething some Suther. He think he Hindrol-xperce?
# Just jack af for. )hobudicsuatay, lgotR!
# Yeah, you're going to traves to him, there (
#
# Epoch 00038: loss improved from 1.10648 to 1.10547, saving model to weights_jerry.hdf5
# Epoch 39/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.0892 - categorical_accuracy: 0.6679
#
# ----- Generating text after Epoch:  38
# ----- diversity: 0.2
# ----- Generating with seed: "ng all over the plac"
# ng all over the place and I have to get the way anything about that start of the second.
# What do you want to get the bank of this whole the coffee show the hand in the concomen with the hall.
# What do you mean you don't even have to get the sitter of the concenna get in the concent.
# I don't know what I can down the makings. There's a little like this what I can get this here.
# Well, I don't know what I can get in the b
# ----- diversity: 0.5
# ----- Generating with seed: "ng all over the plac"
# ng all over the place on the work. What is this?
# What is this?
# What are you doing? You know, the whole the shifferseland with a see there anything about the phone are standing her for this courday matter.
# I don't know it make it trying to nike that poppence the door.
# Hey, I met you think she seem that because you know, I can do that be a word to see him of the concet.
# (to Elaine) All right. (a streeting of the around
# ----- diversity: 1.0
# ----- Generating with seed: "ng all over the plac"
# ng all over the place make this calls you just weire you never gotaster was there? (Jerry pokienct sheme, you can to go out oh Elaine toody ten and she can sure.
# Hello.
# All right. Yeah. Im going to like my face, Vgew, I get over. Streetfeet.
# our cheal.
# Talk with me a little greatme. You care! I'm eating of took is for here.
# Really?
# What I?much?
# I don't even have to get talaic Laurse to her who see that mance like she
# ----- diversity: 1.2
# ----- Generating with seed: "ng all over the plac"
# ng all over the place sho.
# All right, I dannis your crapy.
# Whats good, thy Yange any rachigg'd.
# Tell you don't know what. 'As.
# Hey mojes. That's taking it, talk Now's home on the Deccokened) I think on the teck and Beving it was work.
# HE , (Not introse with NBCCto down the ome?
# Whos my sappres, walk makse weedGet me, I dud I'll stealle good conviouslems)
# Bneen's go.
# Well we feet up with my myster.
# So perpos of rement
#
# Epoch 00039: loss improved from 1.10547 to 1.10072, saving model to weights_jerry.hdf5
# Epoch 40/40
# 851/851 [==============================] - 5s 6ms/step - loss: 1.0788 - categorical_accuracy: 0.6708
#
# ----- Generating text after Epoch:  39
# ----- diversity: 0.2
# ----- Generating with seed: "com) Yeah?
# Come on u"
# com) Yeah?
# Come on up.
# I don't know how you don't get it?
# Oh, thanks into your face, the way anyway. I don't know what the woman and he didn't think I'm going to be the pick the pickly was the work. I'm gonna be all this my face, the way of this.
# Yeah, I don't know what the mays the matter of this many because I was a monther and and he didn't think I can do to get here.
# What are you doing?
# Yeah, yeah.
# Yeah, you don'
# ----- diversity: 0.5
# ----- Generating with seed: "com) Yeah?
# Come on u"
# com) Yeah?
# Come on up this guy in it. And I know.
# Yes you got to have you to do this?
# No. You got to make it a guy in the stupid the monty feeling and I don't think I were in a fave any calaca.
# What is this me?
# Because I lina a steppose for this and they mover on the street with the with a upiduone? How do you had this? I don't know what that I steelack at you don't get it. It was a street to do this his doctor, and
# ----- diversity: 1.0
# ----- Generating with seed: "com) Yeah?
# Come on u"
# com) Yeah?
# Come on umparake if you got to be to chnowing the doors?
# So Marosty mesting very of a night, - Pays would meat! (encery just showes, goYnars Kramer!
# Oh, and , money her starts a forty?
# So that about.
# Alright, Who meal?
# 'THe meance's nothing.. He was babks a winduf I've skidnd three pressing, and uh, I dong you all take it cost sorty.
# You don't know. Kramer even youver we eating on the how if I upent dont i
# ----- diversity: 1.2
# ----- Generating with seed: "com) Yeah?
# Come on u"
# com) Yeah?
# Come on upsex... And Elaine,
# It. Almost- huh-use become expedeally for her! now around?
# (Buss the lwabothereay. You can't end out-Hin up.
# Alright. I know, smefore throws. jacket) th, I would neves Hive trey guy. Come on! Oh, uh, no, its envovionsef up it?!
# No. been if this hucce?
# race, they're feelin'tle.
# Yeah, I'm Lan't Fand how you know wear Hi, George, here you don't linent you go, an ama bad and we get
#
# Epoch 00040: loss improved from 1.10072 to 1.09578, saving model to weights_jerry.hdf5

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-5f15418b3570> in <module>
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined

# %%
data_dir = './data/dev.txt'
print(data_dir)
text = load_data(data_dir)
# Out:
# ./data/dev.txt

# %%
def load_model(weight_file):
    # Load the network weights 
    model = GRU_model(20, vocabulary)
    model.load_weights(weight_file)
    model.summary()
    
    return model

# %%
model = load_model('weights_jerry.hdf5')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               83328
# _________________________________________________________________
# dense (Dense)                (None, 87)                11223
# _________________________________________________________________
# activation (Activation)      (None, 87)                0
# =================================================================
# Total params: 94,551
# Trainable params: 94,551
# Non-trainable params: 0
# _________________________________________________________________

# %%
def generate_text(length, diversity):
    # Get random starting text
    start_index = random.randint(0, len(text) - max_length - 1)
  
    # Defining the generated text
    generated = ''
    sentence = text[start_index: start_index + max_length]
    reference = text[start_index+ max_length: start_index+ max_length+length]
    generated += sentence
  
    # Generating new text of given length
    for i in range(length):
  
            # Initializing the predicition vector
            x_pred = np.zeros((1, max_length, len(vocabulary)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_to_indices[char]] = 1.
  
            # Making the predicitons
            preds = model.predict(x_pred, verbose = 0)[0]
  
            # Getting the index of the next most probable index
            next_index = sample_index(preds, diversity)
  
            # Getting the most probable next character using the mapping built
            next_char = indices_to_char[next_index]
  
            # Generating new text
            generated += next_char
            sentence = sentence[1:] + next_char
    return generated, reference

# %%
print(generate_text(20, 0.2))
# Out:
# ('with all do respect for this my face any', "I would think it's r")

# %%
def BLEU_score(simulation_time, prediction_length):
    avg_BLEU_1 = 0
    avg_BLEU_4 = 0
    length = 20
    diversity=0.2
    for i in range(simulation_time):
        reference, prediction = generate_text(length, diversity)
        BLEU_1 = nltk.translate.bleu_score.sentence_bleu([reference], prediction, weights=(1,0,0,0))
        BLEU_4 = nltk.translate.bleu_score.sentence_bleu([reference], prediction)
        
        avg_BLEU_1 += BLEU_1
        avg_BLEU_4 += BLEU_4
        
    avg_BLEU_1 = avg_BLEU_1 / simulation_time
    avg_BLEU_4 = avg_BLEU_4 / simulation_time
    
    print(f"Cumulative 1-gram: {avg_BLEU_1}")
    print(f"Cumulative 4-gram: {avg_BLEU_4}")

# %%
BLEU_score(100, 20)
# Out:
# /home/jupyter/.local/lib/python3.7/site-packages/nltk/translate/bleu_score.py:516: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /home/jupyter/.local/lib/python3.7/site-packages/nltk/translate/bleu_score.py:516: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /home/jupyter/.local/lib/python3.7/site-packages/nltk/translate/bleu_score.py:516: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Cumulative 1-gram: 0.2624819812758244
# Cumulative 4-gram: 0.03859844449749971

# %%
# def remove_special_chara(text):
#     SPECIAL_WORDS = {'PADDING': '<PAD>'}
#     token_dict = {
#             '.': '||Period||',
#             ',': '||Comma||',
#             '"': '||Quotation_Mark||',
#             ';': '||Semicolon||',
#             '!': '||Exclamation_Mark||',
#             '?': '||Question_Mark||',
#             '(': '||Left_Parentheses||',
#             ')': '||Right_Parentheses||',
#             '-': '||Dash||',
#             '\n': '||Return||'
#             }
#     for key, token in token_dict.items():
#             text = text.replace(" {}".format(token), key)
    
#     text = text.replace('<PAD>', '\n')
    
#     return text

# %%
# from rouge_metric import PyRouge

# def Rouge_score(simulation_time, prediction_length):
#     length = 20
#     diversity=0.2
#     for i in range(simulation_time):
#         reference, prediction = generate_text(length, diversity)
#         reference = remove_special_chara(" " + " ".join(reference))
#         prediction = remove_special_chara(" " + " ".join(prediction))

#         rouge = PyRouge(rouge_n=(1, 2), rouge_l=True, rouge_w=True,
#                     rouge_w_weight=1.2, rouge_s=True, rouge_su=True, skip_gap=4)
#         scores = rouge.evaluate([prediction], [[reference]])
#         print(scores)

# %%
# Rouge_score(1, 200)

# %%
# count the number of words
word_counts = Counter(text).most_common()
word_counts
# Out:
# [(' ', 92908),
#  ('e', 46205),
#  ('t', 37300),
#  ('o', 35463),
#  ('a', 30439),
#  ('n', 25845),
#  ('h', 24605),
#  ('i', 23821),
#  ('s', 21142),
#  ('r', 18997),
#  ('l', 16411),
#  ('u', 14578),
#  ('.', 13042),
#  ('d', 12681),
#  ('y', 11811),
#  ('g', 10514),
#  ('\n', 10239),
#  ('m', 9583),
#  ('w', 8923),
#  ('c', 7630),
#  (',', 6995),
#  ('k', 6048),
#  ("'", 5738),
#  ('p', 5616),
#  ('f', 5588),
#  ('I', 5481),
#  ('b', 5269),
#  ('?', 4445),
#  ('v', 3426),
#  ('W', 2517),
#  ('Y', 1942),
#  ('T', 1705),
#  ('(', 1590),
#  (')', 1588),
#  ('H', 1510),
#  ('!', 1431),
#  ('S', 1347),
#  ('A', 1127),
#  ('O', 1084),
#  ('N', 1027),
#  ('-', 895),
#  ('G', 772),
#  ('j', 725),
#  ('B', 674),
#  ('E', 631),
#  ('C', 612),
#  ('M', 565),
#  ('K', 505),
#  ('x', 493),
#  ('L', 488),
#  ('D', 476),
#  ('J', 408),
#  ('"', 404),
#  ('P', 385),
#  ('R', 356),
#  ('z', 340),
#  ('F', 244),
#  ('U', 220),
#  ('q', 190),
#  ('V', 120),
#  ('0', 71),
#  ('1', 61),
#  ('5', 61),
#  ('*', 56),
#  (';', 49),
#  ('9', 43),
#  ('2', 37),
#  ('8', 35),
#  ('3', 33),
#  ('[', 31),
#  (']', 30),
#  ('4', 26),
#  ('7', 19),
#  ('6', 19),
#  ('Q', 18),
#  ('Z', 12),
#  ('$', 6),
#  ('`', 5),
#  ('/', 4),
#  ('&', 4),
#  ('X', 4),
#  ('%', 2),
#  ('\\', 1),
#  ('<', 1),
#  ('>', 1),
#  ('#', 1),
#  ('_', 1)]

# %%
from collections import Counter
unigram_prob = {}
word_counts = Counter(text).most_common()
for w in word_counts:
    unigram_prob[w[0]] = w[1]

def perplexity_score(simulation_time, prediction_length):
    score = 0.0
    length = 20
    diversity=0.2
    for i in range(simulation_time):
        reference, prediction = generate_text(length, diversity)
        l = 0.0
        for w in prediction:
            l += np.log2(unigram_prob[w])
        l = l / prediction_length
        score += np.power(2, -l)
    score /= simulation_time
    
    return score

# %%
perplexity_score(100, 20)
# Out:
# 4.482171403098487e-05
